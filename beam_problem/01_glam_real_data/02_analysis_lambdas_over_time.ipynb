# %% [markdown]
# # Libraries

# %%
import sys
from pathlib import Path
project_root = Path.cwd().parent
sys.path.insert(0, str(project_root))
from functions import *
from UQpy.distributions import Normal, JointIndependent
import matplotlib as mpl
mpl.rcParams.update({
                        'font.family': 'serif',
                        'mathtext.fontset': 'cm',
                        'axes.unicode_minus': False
                    })
import seaborn as sns
import numpy as np
# Out:
# d:\Documentos\ic_victor\myenv\Lib\site-packages\UQpy\__init__.py:6: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   import pkg_resources

# %% [markdown]
# # Dataset

# %% [markdown]
# ### General data

# %%
n_latent_samples = 1000
n_samples = 10
r   = Normal(loc = 5., scale=0.8)
s   = Normal(loc = 2., scale=0.6)

# %% [markdown]
# ### State limit function

# %%
step_time = 0.0
divs = 10

# %%
joint = JointIndependent(marginals=[r, s])
x_val = joint.rvs(n_samples)
submatrices = np.array_split(x_val, divs)
df, glam_data = g_toy_problem_parallel_with_multiprocessing(submatrices, n_latent_samples, t=step_time)
glam_data
# Out:
#           r         s  lambda 1  lambda 2  lambda 3  lambda 4
# 0  4.997843  3.109111  1.916551  4.822312  0.029136  0.116071
# 1  5.114641  2.522883  2.602606  5.547586  0.057282  0.113377
# 2  4.995951  1.197046  3.809697  8.135522  0.131494  0.153229
# 3  6.043045  2.290904  3.765606  5.521824  0.067997  0.108693
# 4  5.871965  2.048751  3.840069  5.801798  0.087824  0.180668
# 5  5.840138  2.288684  3.561292  4.976574  0.125839  0.224397
# 6  4.317185  2.203131  2.133985  6.259736  0.034809  0.139025
# 7  4.199084  2.332159  1.882229  5.605500  0.111261  0.210153
# 8  4.813314  1.628352  3.192105  6.934994  0.126710  0.176382
# 9  4.750820  2.455719  2.300783  5.332933  0.137583  0.158770

# %%
glam_data.describe()
# Out:
#                r          s   lambda 1   lambda 2   lambda 3   lambda 4
# count  10.000000  10.000000  10.000000  10.000000  10.000000  10.000000
# mean    5.094399   2.207674   2.900492   5.893878   0.090993   0.158076
# std     0.639687   0.514751   0.817890   0.994266   0.041325   0.040199
# min     4.199084   1.197046   1.882229   4.822312   0.029136   0.108693
# 25%     4.766443   2.087346   2.175685   5.380156   0.059961   0.121809
# 50%     4.996897   2.289794   2.897356   5.576543   0.099542   0.156000
# 75%     5.658764   2.424829   3.714527   6.145252   0.126492   0.179596
# max     6.043045   3.109111   3.840069   8.135522   0.137583   0.224397

# %% [markdown]
# # Charts

# %% [markdown]
# ### English version

# %% [markdown]
# #### $\lambda _1$

# %%
### Figure name and DPI
dpi = 600                                                   # Change as you wish
name = 'lambda 1'           # Change as you wish

### Chart dimensions (in centimeters)
b_cm = 12                                                   # Change as you wish
h_cm = 8                                                    # Change as you wish
inches_to_cm = 1 / 2.54
b_input = b_cm * inches_to_cm
h_input = h_cm * inches_to_cm

### Axis and labels (For LateX font format use the dollar sign $)
label_x = 'Resistance ($R$)'                                # Change as you wish
label_y = 'Load ($S$)'                                      # Change as you wish
label_cmap = '$\lambda _1$'                                 # Change as you wish
size_label = 13                                             # Change as you wish
color_label = 'black'                                       # or hexadecimal. Change as you wish
size_axis = 13                                              # Change as you wish
color_axis = 'black'                                        # or hexadecimal. Change as you wish

### Scatter
cmap_type = 'seismic'                                       # Change as you wish. Check matplotlib colormaps documentation: https://matplotlib.org/stable/users/explain/colors/colormaps.html
size_scatter = 25                                           # Change as you wish

### Grid
on_or_off = True
line_width_grid = 0.5                                       # Change as you wish
alpha_grid = 0.3                                            # Change as you wish
style_grid = '-'                                            # Change as you wish
color_grid = 'gray'                                         # or hexadecimal. Change as you wish

### Figure
fig, ax = plt.subplots(figsize=(b_input, h_input))
ax.tick_params(axis='both', which='major', labelsize=size_axis, colors=color_axis)
ax.set_xlabel(label_x, fontsize=size_label, color=color_label)
ax.set_ylabel(label_y, fontsize=size_label, color=color_label)

### Title. Do you need a title? Use the cell bellow:
# ax.set_title('Sine Wave Plot', fontsize=16)

### Config grid
plt.grid(on_or_off, which='both', linestyle=style_grid, linewidth=line_width_grid, color=color_grid, alpha=alpha_grid)

### Plot data
sc = ax.scatter(glam_data['r'], glam_data['s'], c=glam_data[name], cmap=cmap_type, s=size_scatter)
cbar = fig.colorbar(sc, ax=ax)
cbar.set_label(label_cmap, size=size_label, color=color_label)
cbar.ax.tick_params(labelsize=size_axis)

### Save. Do you need save? Use the cell bellow:
fig.savefig(f'z_glam_from_real_data_{name}_{int(step_time)}_en.png', dpi=dpi, bbox_inches='tight')
plt.show()

# %% [markdown]
# #### $\lambda _2$

# %%
### Figure name and DPI
dpi = 600                                                   # Change as you wish
name = 'lambda 2'           # Change as you wish

### Chart dimensions (in centimeters)
b_cm = 12                                                   # Change as you wish
h_cm = 8                                                    # Change as you wish
inches_to_cm = 1 / 2.54
b_input = b_cm * inches_to_cm
h_input = h_cm * inches_to_cm

### Axis and labels (For LateX font format use the dollar sign $)
label_x = 'Resistance ($R$)'                             # Change as you wish
label_y = 'Load ($S$)'                                 # Change as you wish
label_cmap = '$\lambda _2$'                             # Change as you wish
size_label = 13                                             # Change as you wish
color_label = 'black'                                        # or hexadecimal. Change as you wish
size_axis = 13                                              # Change as you wish
color_axis = 'black'                                          # or hexadecimal. Change as you wish

### Scatter
cmap_type = 'seismic'                                          # Change as you wish. Check matplotlib colormaps documentation: https://matplotlib.org/stable/users/explain/colors/colormaps.html
size_scatter = 25                                           # Change as you wish

### Grid
on_or_off = True
line_width_grid = 0.5                                       # Change as you wish
alpha_grid = 0.3                                            # Change as you wish
style_grid = '-'                                            # Change as you wish
color_grid = 'gray'                                         # or hexadecimal. Change as you wish

### Figure
fig, ax = plt.subplots(figsize=(b_input, h_input))
ax.tick_params(axis='both', which='major', labelsize=size_axis, colors=color_axis)
ax.set_xlabel(label_x, fontsize=size_label, color=color_label)
ax.set_ylabel(label_y, fontsize=size_label, color=color_label)

### Title. Do you need a title? Use the cell bellow:
# ax.set_title('Sine Wave Plot', fontsize=16)

### Config grid
plt.grid(on_or_off, which='both', linestyle=style_grid, linewidth=line_width_grid, color=color_grid, alpha=alpha_grid)

### Plot data
sc = ax.scatter(glam_data['r'], glam_data['s'], c=glam_data[name], cmap=cmap_type, s=size_scatter)
cbar = fig.colorbar(sc, ax=ax)
cbar.set_label(label_cmap, size=size_label, color=color_label)
cbar.ax.tick_params(labelsize=size_axis)

### Save. Do you need save? Use the cell bellow:
fig.savefig(f'z_glam_from_real_data_{name}_{int(step_time)}_en.png', dpi=dpi, bbox_inches='tight')
plt.show()

# %% [markdown]
# #### $\lambda _3$

# %%
### Figure name and DPI
dpi = 600                                                   # Change as you wish
name = 'lambda 3'           # Change as you wish

### Chart dimensions (in centimeters)
b_cm = 12                                                   # Change as you wish
h_cm = 8                                                    # Change as you wish
inches_to_cm = 1 / 2.54
b_input = b_cm * inches_to_cm
h_input = h_cm * inches_to_cm

### Axis and labels (For LateX font format use the dollar sign $)
label_x = 'Resistance ($R$)'                             # Change as you wish
label_y = 'Load ($S$)'                                 # Change as you wish
label_cmap = '$\lambda _3$'                             # Change as you wish
size_label = 13                                             # Change as you wish
color_label = 'black'                                        # or hexadecimal. Change as you wish
size_axis = 13                                              # Change as you wish
color_axis = 'black'                                          # or hexadecimal. Change as you wish

### Scatter
cmap_type = 'seismic'                                          # Change as you wish. Check matplotlib colormaps documentation: https://matplotlib.org/stable/users/explain/colors/colormaps.html
size_scatter = 25                                           # Change as you wish

### Grid
on_or_off = True
line_width_grid = 0.5                                       # Change as you wish
alpha_grid = 0.3                                            # Change as you wish
style_grid = '-'                                            # Change as you wish
color_grid = 'gray'                                         # or hexadecimal. Change as you wish

### Figure
fig, ax = plt.subplots(figsize=(b_input, h_input))
ax.tick_params(axis='both', which='major', labelsize=size_axis, colors=color_axis)
ax.set_xlabel(label_x, fontsize=size_label, color=color_label)
ax.set_ylabel(label_y, fontsize=size_label, color=color_label)

### Title. Do you need a title? Use the cell bellow:
# ax.set_title('Sine Wave Plot', fontsize=16)

### Config grid
plt.grid(on_or_off, which='both', linestyle=style_grid, linewidth=line_width_grid, color=color_grid, alpha=alpha_grid)

### Plot data
sc = ax.scatter(glam_data['r'], glam_data['s'], c=glam_data[name], cmap=cmap_type, s=size_scatter)
cbar = fig.colorbar(sc, ax=ax)
cbar.set_label(label_cmap, size=size_label, color=color_label)
cbar.ax.tick_params(labelsize=size_axis)

### Save. Do you need save? Use the cell bellow:
fig.savefig(f'z_glam_from_real_data_{name}_{int(step_time)}_en.png', dpi=dpi, bbox_inches='tight')
plt.show()

# %% [markdown]
# #### $\lambda _4$

# %%
### Figure name and DPI
dpi = 600                                                   # Change as you wish
name = 'lambda 4'           # Change as you wish

### Chart dimensions (in centimeters)
b_cm = 12                                                   # Change as you wish
h_cm = 8                                                    # Change as you wish
inches_to_cm = 1 / 2.54
b_input = b_cm * inches_to_cm
h_input = h_cm * inches_to_cm

### Axis and labels (For LateX font format use the dollar sign $)
label_x = 'Resistance ($R$)'                             # Change as you wish
label_y = 'Load ($S$)'                                 # Change as you wish
label_cmap = '$\lambda _4$'                             # Change as you wish
size_label = 13                                             # Change as you wish
color_label = 'black'                                        # or hexadecimal. Change as you wish
size_axis = 13                                              # Change as you wish
color_axis = 'black'                                          # or hexadecimal. Change as you wish

### Scatter
cmap_type = 'seismic'                                          # Change as you wish. Check matplotlib colormaps documentation: https://matplotlib.org/stable/users/explain/colors/colormaps.html
size_scatter = 25                                           # Change as you wish

### Grid
on_or_off = True
line_width_grid = 0.5                                       # Change as you wish
alpha_grid = 0.3                                            # Change as you wish
style_grid = '-'                                            # Change as you wish
color_grid = 'gray'                                         # or hexadecimal. Change as you wish

### Figure
fig, ax = plt.subplots(figsize=(b_input, h_input))
ax.tick_params(axis='both', which='major', labelsize=size_axis, colors=color_axis)
ax.set_xlabel(label_x, fontsize=size_label, color=color_label)
ax.set_ylabel(label_y, fontsize=size_label, color=color_label)

### Title. Do you need a title? Use the cell bellow:
# ax.set_title('Sine Wave Plot', fontsize=16)

### Config grid
plt.grid(on_or_off, which='both', linestyle=style_grid, linewidth=line_width_grid, color=color_grid, alpha=alpha_grid)

### Plot data
sc = ax.scatter(glam_data['r'], glam_data['s'], c=glam_data[name], cmap=cmap_type, s=size_scatter)
cbar = fig.colorbar(sc, ax=ax)
cbar.set_label(label_cmap, size=size_label, color=color_label)
cbar.ax.tick_params(labelsize=size_axis)

### Save. Do you need save? Use the cell bellow:
fig.savefig(f'z_glam_from_real_data_{name}_{int(step_time)}_en.png', dpi=dpi, bbox_inches='tight')
plt.show()

# %% [markdown]
# ### Portuguese version

# %% [markdown]
# #### $\lambda _1$

# %%
### ome e DPI
dpi = 600                                                   # Change as you wish
name = 'lambda 1'           # Change as you wish

### Chart dimensions (in centimeters)
b_cm = 12                                                   # Change as you wish
h_cm = 8                                                    # Change as you wish
inches_to_cm = 1 / 2.54
b_input = b_cm * inches_to_cm
h_input = h_cm * inches_to_cm

### Axis and labels (For LateX font format use the dollar sign $)
label_x = 'Resistência ($R$)'                             # Change as you wish
label_y = 'Solicitação ($S$)'                                 # Change as you wish
label_cmap = '$\lambda _1$'                             # Change as you wish
size_label = 13                                             # Change as you wish
color_label = 'black'                                        # or hexadecimal. Change as you wish
size_axis = 13                                              # Change as you wish
color_axis = 'black'                                          # or hexadecimal. Change as you wish

### Scatter
cmap_type = 'seismic'                                          # Change as you wish. Check matplotlib colormaps documentation: https://matplotlib.org/stable/users/explain/colors/colormaps.html
size_scatter = 25                                           # Change as you wish

### Grid
on_or_off = True
line_width_grid = 0.5                                       # Change as you wish
alpha_grid = 0.3                                            # Change as you wish
style_grid = '-'                                            # Change as you wish
color_grid = 'gray'                                         # or hexadecimal. Change as you wish

### Figure
fig, ax = plt.subplots(figsize=(b_input, h_input))
ax.tick_params(axis='both', which='major', labelsize=size_axis, colors=color_axis)
ax.set_xlabel(label_x, fontsize=size_label, color=color_label)
ax.set_ylabel(label_y, fontsize=size_label, color=color_label)

### Title. Do you need a title? Use the cell bellow:
# ax.set_title('Sine Wave Plot', fontsize=16)

### Config grid
plt.grid(on_or_off, which='both', linestyle=style_grid, linewidth=line_width_grid, color=color_grid, alpha=alpha_grid)

### Plot data
sc = ax.scatter(glam_data['r'], glam_data['s'], c=glam_data[name], cmap=cmap_type, s=size_scatter)
cbar = fig.colorbar(sc, ax=ax)
cbar.set_label(label_cmap, size=size_label, color=color_label)
cbar.ax.tick_params(labelsize=size_axis)

### Save. Do you need save? Use the cell bellow:
fig.savefig(f'z_glam_from_real_data_{name}_{int(step_time)}_pt.png', dpi=dpi, bbox_inches='tight')
plt.show()

# %% [markdown]
# #### $\lambda _2$

# %%
### ome e DPI
dpi = 600                                                   # Change as you wish
name = 'lambda 2'           # Change as you wish

### Chart dimensions (in centimeters)
b_cm = 12                                                   # Change as you wish
h_cm = 8                                                    # Change as you wish
inches_to_cm = 1 / 2.54
b_input = b_cm * inches_to_cm
h_input = h_cm * inches_to_cm

### Axis and labels (For LateX font format use the dollar sign $)
label_x = 'Resistência ($R$)'                             # Change as you wish
label_y = 'Solicitação ($S$)'                                 # Change as you wish
label_cmap = '$\lambda _2$'                             # Change as you wish
size_label = 13                                             # Change as you wish
color_label = 'black'                                        # or hexadecimal. Change as you wish
size_axis = 13                                              # Change as you wish
color_axis = 'black'                                          # or hexadecimal. Change as you wish

### Scatter
cmap_type = 'seismic'                                          # Change as you wish. Check matplotlib colormaps documentation: https://matplotlib.org/stable/users/explain/colors/colormaps.html
size_scatter = 25                                           # Change as you wish

### Grid
on_or_off = True
line_width_grid = 0.5                                       # Change as you wish
alpha_grid = 0.3                                            # Change as you wish
style_grid = '-'                                            # Change as you wish
color_grid = 'gray'                                         # or hexadecimal. Change as you wish

### Figure
fig, ax = plt.subplots(figsize=(b_input, h_input))
ax.tick_params(axis='both', which='major', labelsize=size_axis, colors=color_axis)
ax.set_xlabel(label_x, fontsize=size_label, color=color_label)
ax.set_ylabel(label_y, fontsize=size_label, color=color_label)

### Title. Do you need a title? Use the cell bellow:
# ax.set_title('Sine Wave Plot', fontsize=16)

### Config grid
plt.grid(on_or_off, which='both', linestyle=style_grid, linewidth=line_width_grid, color=color_grid, alpha=alpha_grid)

### Plot data
sc = ax.scatter(glam_data['r'], glam_data['s'], c=glam_data[name], cmap=cmap_type, s=size_scatter)
cbar = fig.colorbar(sc, ax=ax)
cbar.set_label(label_cmap, size=size_label, color=color_label)
cbar.ax.tick_params(labelsize=size_axis)

### Save. Do you need save? Use the cell bellow:
fig.savefig(f'z_glam_from_real_data_{name}_{int(step_time)}_pt.png', dpi=dpi, bbox_inches='tight')
plt.show()

# %% [markdown]
# #### $\lambda _3$

# %%
### ome e DPI
dpi = 600                                                   # Change as you wish
name = 'lambda 3'           # Change as you wish

### Chart dimensions (in centimeters)
b_cm = 12                                                   # Change as you wish
h_cm = 8                                                    # Change as you wish
inches_to_cm = 1 / 2.54
b_input = b_cm * inches_to_cm
h_input = h_cm * inches_to_cm

### Axis and labels (For LateX font format use the dollar sign $)
label_x = 'Resistência ($R$)'                             # Change as you wish
label_y = 'Solicitação ($S$)'                                 # Change as you wish
label_cmap = '$\lambda _3$'                             # Change as you wish
size_label = 13                                             # Change as you wish
color_label = 'black'                                        # or hexadecimal. Change as you wish
size_axis = 13                                              # Change as you wish
color_axis = 'black'                                          # or hexadecimal. Change as you wish

### Scatter
cmap_type = 'seismic'                                          # Change as you wish. Check matplotlib colormaps documentation: https://matplotlib.org/stable/users/explain/colors/colormaps.html
size_scatter = 25                                           # Change as you wish

### Grid
on_or_off = True
line_width_grid = 0.5                                       # Change as you wish
alpha_grid = 0.3                                            # Change as you wish
style_grid = '-'                                            # Change as you wish
color_grid = 'gray'                                         # or hexadecimal. Change as you wish

### Figure
fig, ax = plt.subplots(figsize=(b_input, h_input))
ax.tick_params(axis='both', which='major', labelsize=size_axis, colors=color_axis)
ax.set_xlabel(label_x, fontsize=size_label, color=color_label)
ax.set_ylabel(label_y, fontsize=size_label, color=color_label)

### Title. Do you need a title? Use the cell bellow:
# ax.set_title('Sine Wave Plot', fontsize=16)

### Config grid
plt.grid(on_or_off, which='both', linestyle=style_grid, linewidth=line_width_grid, color=color_grid, alpha=alpha_grid)

### Plot data
sc = ax.scatter(glam_data['r'], glam_data['s'], c=glam_data[name], cmap=cmap_type, s=size_scatter)
cbar = fig.colorbar(sc, ax=ax)
cbar.set_label(label_cmap, size=size_label, color=color_label)
cbar.ax.tick_params(labelsize=size_axis)

### Save. Do you need save? Use the cell bellow:
fig.savefig(f'z_glam_from_real_data_{name}_{int(step_time)}_pt.png', dpi=dpi, bbox_inches='tight')
plt.show()

# %% [markdown]
# #### $\lambda _4$

# %%
### ome e DPI
dpi = 600                                                   # Change as you wish
name = 'lambda 4'           # Change as you wish

### Chart dimensions (in centimeters)
b_cm = 12                                                   # Change as you wish
h_cm = 8                                                    # Change as you wish
inches_to_cm = 1 / 2.54
b_input = b_cm * inches_to_cm
h_input = h_cm * inches_to_cm

### Axis and labels (For LateX font format use the dollar sign $)
label_x = 'Resistência ($R$)'                             # Change as you wish
label_y = 'Solicitação ($S$)'                                 # Change as you wish
label_cmap = '$\lambda _4$'                             # Change as you wish
size_label = 13                                             # Change as you wish
color_label = 'black'                                        # or hexadecimal. Change as you wish
size_axis = 13                                              # Change as you wish
color_axis = 'black'                                          # or hexadecimal. Change as you wish

### Scatter
cmap_type = 'seismic'                                          # Change as you wish. Check matplotlib colormaps documentation: https://matplotlib.org/stable/users/explain/colors/colormaps.html
size_scatter = 25                                           # Change as you wish

### Grid
on_or_off = True
line_width_grid = 0.5                                       # Change as you wish
alpha_grid = 0.3                                            # Change as you wish
style_grid = '-'                                            # Change as you wish
color_grid = 'gray'                                         # or hexadecimal. Change as you wish

### Figure
fig, ax = plt.subplots(figsize=(b_input, h_input))
ax.tick_params(axis='both', which='major', labelsize=size_axis, colors=color_axis)
ax.set_xlabel(label_x, fontsize=size_label, color=color_label)
ax.set_ylabel(label_y, fontsize=size_label, color=color_label)

### Title. Do you need a title? Use the cell bellow:
# ax.set_title('Sine Wave Plot', fontsize=16)

### Config grid
plt.grid(on_or_off, which='both', linestyle=style_grid, linewidth=line_width_grid, color=color_grid, alpha=alpha_grid)

### Plot data
sc = ax.scatter(glam_data['r'], glam_data['s'], c=glam_data[name], cmap=cmap_type, s=size_scatter)
cbar = fig.colorbar(sc, ax=ax)
cbar.set_label(label_cmap, size=size_label, color=color_label)
cbar.ax.tick_params(labelsize=size_axis)

### Save. Do you need save? Use the cell bellow:
fig.savefig(f'z_glam_from_real_data_{name}_{int(step_time)}_pt.png', dpi=dpi, bbox_inches='tight')
plt.show()
