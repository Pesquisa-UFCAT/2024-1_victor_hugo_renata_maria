# %% [markdown]
# # 1. LIBRARIES

# %%
import os
import sys
from pathlib import Path

# Add project root to sys.path to allow imports from functions_final.py
project_root = Path.cwd().parent
sys.path.insert(0, str(project_root))

import dill
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
import matplotlib as mpl
import seaborn as sns
from sklearn.metrics import mean_squared_error, r2_score

# Import functions from functions_final.py
from functions_final_parallel import *
from UQpy.distributions import Uniform, JointIndependent

# Set matplotlib parameters for better aesthetics
mpl.rcParams.update({
                        'font.family': 'serif',
                        'mathtext.fontset': 'cm',
                        'axes.unicode_minus': False,
                        'figure.dpi': 100
                    })

# %% [markdown]
# # 2. LOADING THE CARBONATION MODEL

# %% [markdown]
# ### 2.1 Load

# %%
# Path to the trained model
# name_best_model = r'D:\Documentos\ic_victor\beam_problem_1\model_NeuralNetwork_MLP_fold_4.pkl'
# name_best_model = r'/home/wmpjrufg/Documents/2024-1_victor_hugo_renata_maria/beam_problem_1/model_NeuralNetwork_MLP_fold_4.pkl'
# name_best_model = r'D:\py\2024-1_victor_hugo_renata_maria\beam_problem_1\model_NeuralNetwork_MLP_fold_4.pkl'
# name_best_model = r'D:\github\2024-1_victor_hugo_renata_maria\beam_problem_1\model_NeuralNetwork_MLP_fold_4.pkl'
name_best_model = r'/home/tempestade/Documentos/2024-1_victor_hugo_renata_maria/beam_problem_1/model_NeuralNetwork_MLP_fold_4.pkl'

# Load the model
model = joblib.load(name_best_model)
print("Carbonation model loaded successfully!")
print(f"   Expected features: {model.feature_names_in_}")
# Out:
# Carbonation model loaded successfully!
#    Expected features: ['CO2 (%)' 'fc (MPa)' 'RH (%)' 'Type of cement' 'Exposure conditions'
#  't (years)']

# %% [markdown]
# ### 2.2 Testing model

# %%
mat = {
        'f_ck [MPa]': 30,
        'Type of cement': 2
      }
expo = {
          'Installation year': 1990,
          'Exposure conditions': 2,
          'Relative humidity [%]': 60
        }
geo = {'cover[mm]':30}
load = {}
predictor = CO2Predictor()
beam_with_rh = Beam(geo=geo, mat=mat, load=load, expo=expo)
predictor.set_beam(beam_with_rh)
profile = predictor.carbonation_profile(model_=model, lifetime=150)

# %% [markdown]
# ### 2.3 Carbonation profile over time

# %%
profile
# Out:
#     calendar year  t (years)  CO2 (%)  carbonation depth (mm)
# 0            1990          0  0.03574                2.185264
# 1            2000         10  0.03690               13.843039
# 2            2010         20  0.03893               19.512542
# 3            2020         30  0.04132               24.492433
# 4            2030         40  0.04407               28.402407
# 5            2040         50  0.04718               31.645972
# 6            2050         60  0.05065               34.647134
# 7            2060         70  0.05448               37.518476
# 8            2070         80  0.05867               40.403024
# 9            2080         90  0.06322               43.517887
# 10           2090        100  0.06813               46.441706
# 11           2100        110  0.07340               49.123111
# 12           2110        120  0.07903               51.861687
# 13           2120        130  0.08502               54.725327
# 14           2130        140  0.09137               57.751327
# 15           2140        150  0.09808               59.878006

# %% [markdown]
# ### 2.4 Test carbonation depth at 2025

# %%
carb_depth_mm = predictor.carbonation_depth_at_time(profile, 2025)
carb_depth_mm
# Out:
# 26.44741990254805

# %% [markdown]
# # 3. DEFINITION OF RANDOM VARIABLES
#
# Defines the probability distributions for the input variables:
# - Concrete compressive strength ($f_{ck}$);
# - Relative humidity (RH).
# - Cover depth (cov).

# %% [markdown]
# ### 3.1 Design variables

# %%
fck_min = 20 # MPa
fck_max = 50 # MPa
rh_min  = 20 # %
rh_max  = 80 # %
cov_min = 20  # mm
cov_max = 60  # mm

# %% [markdown]
# ### 3.2 Fixed parameters for the analysis

# %%
cement_type          = 3
installation_year    = 1990
exposure_conditions  = 2
n_samples            = 1000       # Number of design samples. Use 1 for testing one sample
n_latent_samples     = 5000       # Number of latent samples per design sample
n_samples_validation = 200        # Number of validation samples
n_lambdas            = 4          # Number of λs to be predicted (λ1, λ2, λ3, λ4)

# %% [markdown]
# ### 3.3 Samples

# %%
# Distributions of random variables
fck_dist = Uniform(loc=fck_min, scale=fck_max - fck_min)
rh_dist  = Uniform(loc=rh_min, scale=rh_max - rh_min)
cov_dist = Uniform(loc=cov_min, scale=cov_max - cov_min)

# Joint distribution
joint = JointIndependent(marginals=[fck_dist, rh_dist, cov_dist])

# Generate samples
x_pce_rvs = joint.rvs(n_samples)

# Report sample statistics
print("Samples generated successfully!")
print(f"   Number of design samples: {n_samples}")
print(f"   Number of latent samples per design sample: {n_latent_samples}")
print(f"   Total simulations: {n_samples * n_latent_samples}")
print("\nSample statistics:")
print(f"   fck:      {x_pce_rvs[:, 0].min():.1f} - {x_pce_rvs[:, 0].max():.1f} MPa (mean: {x_pce_rvs[:, 0].mean():.1f} MPa)")
print(f"   RH:       {x_pce_rvs[:, 1].min():.1f} - {x_pce_rvs[:, 1].max():.1f}% (mean: {x_pce_rvs[:, 1].mean():.1f}%)")
print(f"   cover:    {x_pce_rvs[:, 2].min():.1f} - {x_pce_rvs[:, 2].max():.1f} mm (mean: {x_pce_rvs[:, 2].mean():.1f} mm)")
# Out:
# Samples generated successfully!
#    Number of design samples: 1000
#    Number of latent samples per design sample: 5000
#    Total simulations: 5000000
#
# Sample statistics:
#    fck:      20.1 - 50.0 MPa (mean: 34.7 MPa)
#    RH:       20.1 - 79.9% (mean: 49.8%)
#    cover:    20.0 - 59.9 mm (mean: 39.9 mm)

# %% [markdown]
# # 4. EVALUATION OF CARBONATION PROGRESS USING GENERALIZED LAMBDA DISTRIBUTION

# %% [markdown]
# ### 4.1 Step time

# %%
times               = np.linspace(0, 150, 10, endpoint=True)  # Time points for carbonation depth prediction
# times               = [10, 20, 30, 40]
complete_model_list = []
pce_dataset         = []
times
# Out:
# array([  0.        ,  16.66666667,  33.33333333,  50.        ,
#         66.66666667,  83.33333333, 100.        , 116.66666667,
#        133.33333333, 150.        ])

# %% [markdown]
# ### 4.2 Loop over design samples

# %%
print("="*60)
print("BUILDING THE DURABILITY EMULATOR")
print("="*60)

for t in times:
    # ============================================================
    # EMULATOR FUNCTION - CARBONATION DEPTH AND LAMBDAS
    # ============================================================
    print(f'\n{"-"*40}')
    print(f'PROCESSING EMULATOR FOR TIME STEP: {t} years')
    print(f'{"-"*40}')
    df_full, df_unique = emulator_function_time_durability(
                                                                x=x_pce_rvs,
                                                                names_x_variables=["fck", "rh", "cov"],
                                                                carb_model=model,
                                                                cement_type=cement_type,
                                                                installation_year=installation_year,
                                                                exposure_conditions=exposure_conditions,
                                                                time_step=t,
                                                                n_latent_samples=n_latent_samples,
                                                                verbose=False
                                                            )
    # Save the dataset for this time step
    filename = f'dataset_full_{t}_install_{installation_year}_cement_{cement_type}_exposure_{exposure_conditions}.pkl'
    with open(filename, 'wb') as f:
        dill.dump(df_full, f)
    filename = f'dataset_unique_{t}_install_{installation_year}_cement_{cement_type}_exposure_{exposure_conditions}.pkl'
    with open(filename, 'wb') as f:
        dill.dump(df_unique, f)
    print(f'1. The dataset has been saved!')
    # =============================================================
    # BUILDING THE PCE METAMODEL
    # =============================================================
    lambda_cols      = ['lambda 1', 'lambda 2', 'lambda 3', 'lambda 4']
    y_pce_rvs        = df_unique[lambda_cols].to_numpy()
    max_degree       = 3
    polynomial_basis = TotalDegreeBasis(joint, max_degree)
    least_squares    = LeastSquareRegression()
    pce_metamodel    = PolynomialChaosExpansion(polynomial_basis=polynomial_basis, regression_method=least_squares)                                                                                                        
    # Train
    pce_metamodel.fit(x_pce_rvs, y_pce_rvs)
    # Save the PCE metamodel for this time step
    filename = f'pce_metamodel_{t}_install_{installation_year}_cement_{cement_type}_exposure_{exposure_conditions}.pkl'
    with open(filename, 'wb') as f:
        dill.dump(pce_metamodel, f)
    print(f'2. PCE training dataset has been saved!')
    # =============================================================
    # VALIDATION THE PCE METAMODEL
    # =============================================================
    x_pce_rvs_val = joint.rvs(n_samples_validation)
    df_full_val, df_unique_val = emulator_function_time_durability(
                                                                        x=x_pce_rvs_val,
                                                                        names_x_variables=["fck", "rh", "cov"],
                                                                        carb_model=model,
                                                                        cement_type=cement_type,
                                                                        installation_year=installation_year,
                                                                        exposure_conditions=exposure_conditions,
                                                                        time_step=t,
                                                                        n_latent_samples=n_latent_samples,
                                                                        verbose=False
                                                                    )
    lambda_cols      = ['lambda 1', 'lambda 2', 'lambda 3', 'lambda 4']
    y_pce_val_true   = df_unique_val[lambda_cols].to_numpy()
    y_pce_val_pred   = pce_metamodel.predict(x_pce_rvs_val)
    mse_por_lambda   = []
    r2_por_lambda    = []
    for ii in range(n_lambdas):
        verdade = y_pce_val_true[:, ii]
        predito = y_pce_val_pred[:, ii]
        # MSE computing
        mse = mean_squared_error(verdade, predito)
        mse_por_lambda.append(mse)
        # R² computing
        r2 = r2_score(verdade, predito)
        r2_por_lambda.append(r2)
    statistics_ = pd.DataFrame({'MSE λ1': mse_por_lambda[0], 'MSE λ2': mse_por_lambda[1], 'MSE λ3': mse_por_lambda[2], 'MSE λ4': mse_por_lambda[3], 'R² λ1': r2_por_lambda[0], 'R² λ2': r2_por_lambda[1], 'R² λ3': r2_por_lambda[2], 'R² λ4': r2_por_lambda[3]}, index=[0])
    filename_stats = f'pce_validation_stats_{t}_install_{installation_year}_cement_{cement_type}_exposure_{exposure_conditions}.pkl'
    with open(filename_stats, 'wb') as f:
        dill.dump(statistics_, f)
    print(f'3. PCE statistcs has been saved!')
# Out:
# ============================================================
# BUILDING THE DURABILITY EMULATOR
# ============================================================
#
# ----------------------------------------
# PROCESSING EMULATOR FOR TIME STEP: 0.0 years
# ----------------------------------------
# 1. The dataset has been saved!
# 2. PCE training dataset has been saved!
# 3. PCE statistcs has been saved!
#
# ----------------------------------------
# PROCESSING EMULATOR FOR TIME STEP: 16.666666666666668 years
# ----------------------------------------
# 1. The dataset has been saved!
# 2. PCE training dataset has been saved!
# 3. PCE statistcs has been saved!
#
# ----------------------------------------
# PROCESSING EMULATOR FOR TIME STEP: 33.333333333333336 years
# ----------------------------------------
# 1. The dataset has been saved!
# 2. PCE training dataset has been saved!
# 3. PCE statistcs has been saved!
#
# ----------------------------------------
# PROCESSING EMULATOR FOR TIME STEP: 50.0 years
# ----------------------------------------
# 1. The dataset has been saved!
# 2. PCE training dataset has been saved!
# 3. PCE statistcs has been saved!
#
# ----------------------------------------
# PROCESSING EMULATOR FOR TIME STEP: 66.66666666666667 years
# ----------------------------------------
# 1. The dataset has been saved!
# 2. PCE training dataset has been saved!
# 3. PCE statistcs has been saved!
#
# ----------------------------------------
# PROCESSING EMULATOR FOR TIME STEP: 83.33333333333334 years
# ----------------------------------------
# 1. The dataset has been saved!
# 2. PCE training dataset has been saved!
# 3. PCE statistcs has been saved!
#
# ----------------------------------------
# PROCESSING EMULATOR FOR TIME STEP: 100.0 years
# ----------------------------------------
# 1. The dataset has been saved!
# 2. PCE training dataset has been saved!
# 3. PCE statistcs has been saved!
#
# ----------------------------------------
# PROCESSING EMULATOR FOR TIME STEP: 116.66666666666667 years
# ----------------------------------------
# 1. The dataset has been saved!
# 2. PCE training dataset has been saved!
# Process ForkPoolWorker-483:
# Process ForkPoolWorker-496:
# Process ForkPoolWorker-506:
# Process ForkPoolWorker-494:
# Process ForkPoolWorker-487:
# Process ForkPoolWorker-491:
# Process ForkPoolWorker-481:
# Process ForkPoolWorker-500:
# Process ForkPoolWorker-492:
# Process ForkPoolWorker-503:
# Process ForkPoolWorker-505:
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
# Traceback (most recent call last):
# Process ForkPoolWorker-507:
#   File "/usr/lib/python3.10/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/multiprocessing/pool.py", line 131, in worker
#     put((job, i, result))
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/multiprocessing/pool.py", line 51, in starmapstar
#     return list(itertools.starmap(args[0], args[1]))
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.10/multiprocessing/queues.py", line 376, in put
#     with self._wlock:
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.10/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/tempestade/Documentos/2024-1_victor_hugo_renata_maria/beam_problem_1/functions_final_parallel.py", line 543, in _process_design_point
#     depths = np.asarray(carb_model.predict(batch_df), dtype=float).reshape(n_latent_samples, n_grid)
#   File "/home/tempestade/Documentos/2024-1_victor_hugo_renata_maria/env/lib/python3.10/site-packages/sklearn/pipeline.py", line 603, in predict
#     return self.steps[-1][1].predict(Xt, **params)
# Traceback (most recent call last):
#   File "/home/tempestade/Documentos/2024-1_victor_hugo_renata_maria/env/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py", line 1598, in predict
#     return self._predict(X)
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/home/tempestade/Documentos/2024-1_victor_hugo_renata_maria/env/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py", line 1602, in _predict
#     y_pred = self._forward_pass_fast(X, check_input=check_input)
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
# Process ForkPoolWorker-493:
#   File "/home/tempestade/Documentos/2024-1_victor_hugo_renata_maria/env/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py", line 215, in _forward_pass_fast
#     activation = safe_sparse_dot(activation, self.coefs_[i])
#   File "/usr/lib/python3.10/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#   File "/usr/lib/python3.10/multiprocessing/pool.py", line 51, in starmapstar
#     return list(itertools.starmap(args[0], args[1]))
#   File "/home/tempestade/Documentos/2024-1_victor_hugo_renata_maria/env/lib/python3.10/site-packages/sklearn/utils/extmath.py", line 211, in safe_sparse_dot
#     sparse.issparse(a)
# Traceback (most recent call last):
# Process ForkPoolWorker-488:
#   File "/home/tempestade/Documentos/2024-1_victor_hugo_renata_maria/env/lib/python3.10/site-packages/scipy/sparse/_base.py", line 1388, in issparse
#     def issparse(x):
#   File "/home/tempestade/Documentos/2024-1_victor_hugo_renata_maria/beam_problem_1/functions_final_parallel.py", line 533, in _process_design_point
#     batch_df = pd.DataFrame({
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
# Process ForkPoolWorker-495:
#   File "/home/tempestade/Documentos/2024-1_victor_hugo_renata_maria/env/lib/python3.10/site-packages/pandas/core/frame.py", line 782, in __init__
#     mgr = dict_to_mgr(data, index, columns, dtype=dtype, copy=copy, typ=manager)
#   File "/usr/lib/python3.10/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#   File "/home/tempestade/Documentos/2024-1_victor_hugo_renata_maria/env/lib/python3.10/site-packages/pandas/core/internals/construction.py", line 503, in dict_to_mgr
#     return arrays_to_mgr(arrays, columns, index, dtype=dtype, typ=typ, consolidate=copy)
#   File "/usr/lib/python3.10/multiprocessing/pool.py", line 51, in starmapstar
#     return list(itertools.starmap(args[0], args[1]))
#   File "/home/tempestade/Documentos/2024-1_victor_hugo_renata_maria/env/lib/python3.10/site-packages/pandas/core/internals/construction.py", line 152, in arrays_to_mgr
#     return create_block_manager_from_column_arrays(
# KeyboardInterrupt
# Traceback (most recent call last):
#   File "/home/tempestade/Documentos/2024-1_victor_hugo_renata_maria/beam_problem_1/functions_final_parallel.py", line 543, in _process_design_point
#     depths = np.asarray(carb_model.predict(batch_df), dtype=float).reshape(n_latent_samples, n_grid)
#   File "/home/tempestade/Documentos/2024-1_victor_hugo_renata_maria/env/lib/python3.10/site-packages/pandas/core/internals/managers.py", line 2158, in create_block_manager_from_column_arrays
#     blocks = _form_blocks(arrays, consolidate, refs)
#   File "/home/tempestade/Documentos/2024-1_victor_hugo_renata_maria/env/lib/python3.10/site-packages/sklearn/pipeline.py", line 603, in predict
#     return self.steps[-1][1].predict(Xt, **params)
#   File "/home/tempestade/Documentos/2024-1_victor_hugo_renata_maria/env/lib/python3.10/site-packages/pandas/core/internals/managers.py", line 2231, in _form_blocks
#     values, placement = _stack_arrays(list(tup_block), dtype)
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/home/tempestade/Documentos/2024-1_victor_hugo_renata_maria/env/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py", line 1598, in predict
#     return self._predict(X)
# Traceback (most recent call last):
#   File "/home/tempestade/Documentos/2024-1_victor_hugo_renata_maria/env/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py", line 1602, in _predict
#     y_pred = self._forward_pass_fast(X, check_input=check_input)
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/tempestade/Documentos/2024-1_victor_hugo_renata_maria/env/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py", line 215, in _forward_pass_fast
#     activation = safe_sparse_dot(activation, self.coefs_[i])
#   File "/home/tempestade/Documentos/2024-1_victor_hugo_renata_maria/env/lib/python3.10/site-packages/pandas/core/internals/managers.py", line 2196, in _grouping_func
#     def _grouping_func(tup: tuple[int, ArrayLike]) -> tuple[int, DtypeObj]:
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
# KeyboardInterrupt
#   File "/usr/lib/python3.10/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.10/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.10/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#   File "/usr/lib/python3.10/multiprocessing/pool.py", line 51, in starmapstar
#     return list(itertools.starmap(args[0], args[1]))
#   File "/usr/lib/python3.10/multiprocessing/pool.py", line 131, in worker
#     put((job, i, result))
#   File "/home/tempestade/Documentos/2024-1_victor_hugo_renata_maria/env/lib/python3.10/site-packages/sklearn/utils/extmath.py", line 211, in safe_sparse_dot
#     sparse.issparse(a)
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.10/multiprocessing/pool.py", line 51, in starmapstar
#     return list(itertools.starmap(args[0], args[1]))
#   File "/usr/lib/python3.10/multiprocessing/pool.py", line 131, in worker
#     put((job, i, result))
# KeyboardInterrupt
#   File "/usr/lib/python3.10/multiprocessing/pool.py", line 51, in starmapstar
#     return list(itertools.starmap(args[0], args[1]))
#   File "/home/tempestade/Documentos/2024-1_victor_hugo_renata_maria/beam_problem_1/functions_final_parallel.py", line 543, in _process_design_point
#     depths = np.asarray(carb_model.predict(batch_df), dtype=float).reshape(n_latent_samples, n_grid)
#   File "/usr/lib/python3.10/multiprocessing/queues.py", line 376, in put
#     with self._wlock:
#   File "/usr/lib/python3.10/multiprocessing/pool.py", line 131, in worker
#     put((job, i, result))
#   File "/home/tempestade/Documentos/2024-1_victor_hugo_renata_maria/env/lib/python3.10/site-packages/sklearn/pipeline.py", line 603, in predict
#     return self.steps[-1][1].predict(Xt, **params)
#   File "/usr/lib/python3.10/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/usr/lib/python3.10/multiprocessing/queues.py", line 376, in put
#     with self._wlock:
#   File "/home/tempestade/Documentos/2024-1_victor_hugo_renata_maria/env/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py", line 1598, in predict
#     return self._predict(X)
#   File "/home/tempestade/Documentos/2024-1_victor_hugo_renata_maria/beam_problem_1/functions_final_parallel.py", line 543, in _process_design_point
#     depths = np.asarray(carb_model.predict(batch_df), dtype=float).reshape(n_latent_samples, n_grid)
#   File "/home/tempestade/Documentos/2024-1_victor_hugo_renata_maria/env/lib/python3.10/site-packages/scipy/sparse/_base.py", line 1388, in issparse
#     def issparse(x):
#   File "/home/tempestade/Documentos/2024-1_victor_hugo_renata_maria/beam_problem_1/functions_final_parallel.py", line 543, in _process_design_point
#     depths = np.asarray(carb_model.predict(batch_df), dtype=float).reshape(n_latent_samples, n_grid)
# KeyboardInterrupt
#   File "/usr/lib/python3.10/multiprocessing/queues.py", line 377, in put
#     self._writer.send_bytes(obj)
#   File "/home/tempestade/Documentos/2024-1_victor_hugo_renata_maria/env/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py", line 1602, in _predict
#     y_pred = self._forward_pass_fast(X, check_input=check_input)
#   File "/usr/lib/python3.10/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/tempestade/Documentos/2024-1_victor_hugo_renata_maria/env/lib/python3.10/site-packages/sklearn/pipeline.py", line 603, in predict
#     return self.steps[-1][1].predict(Xt, **params)
#   File "/home/tempestade/Documentos/2024-1_victor_hugo_renata_maria/env/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py", line 215, in _forward_pass_fast
#     activation = safe_sparse_dot(activation, self.coefs_[i])
#   File "/home/tempestade/Documentos/2024-1_victor_hugo_renata_maria/env/lib/python3.10/site-packages/sklearn/utils/extmath.py", line 211, in safe_sparse_dot
#     sparse.issparse(a)
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/tempestade/Documentos/2024-1_victor_hugo_renata_maria/env/lib/python3.10/site-packages/sklearn/pipeline.py", line 603, in predict
#     return self.steps[-1][1].predict(Xt, **params)
#   File "/home/tempestade/Documentos/2024-1_victor_hugo_renata_maria/env/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py", line 1598, in predict
#     return self._predict(X)
#   File "/home/tempestade/Documentos/2024-1_victor_hugo_renata_maria/env/lib/python3.10/site-packages/scipy/sparse/_base.py", line 1388, in issparse
#     def issparse(x):
# Process ForkPoolWorker-489:
#   File "/usr/lib/python3.10/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/usr/lib/python3.10/multiprocessing/pool.py", line 131, in worker
#     put((job, i, result))
# Traceback (most recent call last):
# KeyboardInterrupt
#   File "/home/tempestade/Documentos/2024-1_victor_hugo_renata_maria/env/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py", line 1602, in _predict
#     y_pred = self._forward_pass_fast(X, check_input=check_input)
#   File "/usr/lib/python3.10/multiprocessing/connection.py", line 200, in send_bytes
#     self._send_bytes(m[offset:offset + size])
# Traceback (most recent call last):
#   File "/home/tempestade/Documentos/2024-1_victor_hugo_renata_maria/env/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py", line 1598, in predict
#     return self._predict(X)
# Process ForkPoolWorker-490:
#   File "/home/tempestade/Documentos/2024-1_victor_hugo_renata_maria/env/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py", line 215, in _forward_pass_fast
#     activation = safe_sparse_dot(activation, self.coefs_[i])
#   File "/usr/lib/python3.10/multiprocessing/queues.py", line 376, in put
#     with self._wlock:
#   File "/usr/lib/python3.10/multiprocessing/connection.py", line 405, in _send_bytes
#     self._send(buf)
#   File "/home/tempestade/Documentos/2024-1_victor_hugo_renata_maria/env/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py", line 1602, in _predict
#     y_pred = self._forward_pass_fast(X, check_input=check_input)
#   File "/usr/lib/python3.10/multiprocessing/pool.py", line 51, in starmapstar
#     return list(itertools.starmap(args[0], args[1]))
# Process ForkPoolWorker-502:
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/home/tempestade/Documentos/2024-1_victor_hugo_renata_maria/env/lib/python3.10/site-packages/sklearn/utils/extmath.py", line 211, in safe_sparse_dot
#     sparse.issparse(a)
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/tempestade/Documentos/2024-1_victor_hugo_renata_maria/beam_problem_1/functions_final_parallel.py", line 543, in _process_design_point
#     depths = np.asarray(carb_model.predict(batch_df), dtype=float).reshape(n_latent_samples, n_grid)
#   File "/usr/lib/python3.10/multiprocessing/connection.py", line 368, in _send
#     n = write(self._handle, buf)
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#   File "/home/tempestade/Documentos/2024-1_victor_hugo_renata_maria/env/lib/python3.10/site-packages/scipy/sparse/_base.py", line 1388, in issparse
#     def issparse(x):
#   File "/usr/lib/python3.10/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/home/tempestade/Documentos/2024-1_victor_hugo_renata_maria/env/lib/python3.10/site-packages/sklearn/pipeline.py", line 603, in predict
#     return self.steps[-1][1].predict(Xt, **params)
#   File "/home/tempestade/Documentos/2024-1_victor_hugo_renata_maria/env/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py", line 218, in _forward_pass_fast
#     hidden_activation(activation)
# KeyboardInterrupt
#   File "/usr/lib/python3.10/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#   File "/usr/lib/python3.10/multiprocessing/pool.py", line 51, in starmapstar
#     return list(itertools.starmap(args[0], args[1]))
#   File "/home/tempestade/Documentos/2024-1_victor_hugo_renata_maria/env/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py", line 1598, in predict
#     return self._predict(X)
#   File "/usr/lib/python3.10/multiprocessing/pool.py", line 51, in starmapstar
#     return list(itertools.starmap(args[0], args[1]))
#   File "/home/tempestade/Documentos/2024-1_victor_hugo_renata_maria/env/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py", line 1602, in _predict
#     y_pred = self._forward_pass_fast(X, check_input=check_input)
#   File "/home/tempestade/Documentos/2024-1_victor_hugo_renata_maria/beam_problem_1/functions_final_parallel.py", line 543, in _process_design_point
#     depths = np.asarray(carb_model.predict(batch_df), dtype=float).reshape(n_latent_samples, n_grid)
#   File "/home/tempestade/Documentos/2024-1_victor_hugo_renata_maria/env/lib/python3.10/site-packages/sklearn/pipeline.py", line 603, in predict
#     return self.steps[-1][1].predict(Xt, **params)
#   File "/home/tempestade/Documentos/2024-1_victor_hugo_renata_maria/env/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py", line 1598, in predict
#     return self._predict(X)
#   File "/home/tempestade/Documentos/2024-1_victor_hugo_renata_maria/env/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py", line 1602, in _predict
#     y_pred = self._forward_pass_fast(X, check_input=check_input)
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/tempestade/Documentos/2024-1_victor_hugo_renata_maria/env/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py", line 218, in _forward_pass_fast
#     hidden_activation(activation)
#   File "/home/tempestade/Documentos/2024-1_victor_hugo_renata_maria/beam_problem_1/functions_final_parallel.py", line 543, in _process_design_point
#     depths = np.asarray(carb_model.predict(batch_df), dtype=float).reshape(n_latent_samples, n_grid)
#   File "/home/tempestade/Documentos/2024-1_victor_hugo_renata_maria/env/lib/python3.10/site-packages/sklearn/neural_network/_base.py", line 54, in inplace_relu
#     np.maximum(X, 0, out=X)
#   File "/usr/lib/python3.10/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
# KeyboardInterrupt
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.10/multiprocessing/pool.py", line 51, in starmapstar
#     return list(itertools.starmap(args[0], args[1]))
#   File "/usr/lib/python3.10/multiprocessing/pool.py", line 131, in worker
#     put((job, i, result))
#   File "/home/tempestade/Documentos/2024-1_victor_hugo_renata_maria/env/lib/python3.10/site-packages/sklearn/neural_network/_base.py", line 54, in inplace_relu
#     np.maximum(X, 0, out=X)
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/home/tempestade/Documentos/2024-1_victor_hugo_renata_maria/env/lib/python3.10/site-packages/sklearn/pipeline.py", line 603, in predict
#     return self.steps[-1][1].predict(Xt, **params)
#   File "/usr/lib/python3.10/multiprocessing/queues.py", line 376, in put
#     with self._wlock:
#   File "/usr/lib/python3.10/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
# Process ForkPoolWorker-501:
#   File "/home/tempestade/Documentos/2024-1_victor_hugo_renata_maria/beam_problem_1/functions_final_parallel.py", line 543, in _process_design_point
#     depths = np.asarray(carb_model.predict(batch_df), dtype=float).reshape(n_latent_samples, n_grid)
#   File "/home/tempestade/Documentos/2024-1_victor_hugo_renata_maria/env/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py", line 218, in _forward_pass_fast
#     hidden_activation(activation)
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/multiprocessing/pool.py", line 51, in starmapstar
#     return list(itertools.starmap(args[0], args[1]))
#   File "/usr/lib/python3.10/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/tempestade/Documentos/2024-1_victor_hugo_renata_maria/env/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py", line 1598, in predict
#     return self._predict(X)
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
# KeyboardInterrupt
#   File "/home/tempestade/Documentos/2024-1_victor_hugo_renata_maria/env/lib/python3.10/site-packages/sklearn/neural_network/_base.py", line 54, in inplace_relu
#     np.maximum(X, 0, out=X)
#   File "/usr/lib/python3.10/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#   File "/usr/lib/python3.10/multiprocessing/pool.py", line 51, in starmapstar
#     return list(itertools.starmap(args[0], args[1]))
# Process ForkPoolWorker-509:
#   File "/home/tempestade/Documentos/2024-1_victor_hugo_renata_maria/beam_problem_1/functions_final_parallel.py", line 543, in _process_design_point
#     depths = np.asarray(carb_model.predict(batch_df), dtype=float).reshape(n_latent_samples, n_grid)
#   File "/home/tempestade/Documentos/2024-1_victor_hugo_renata_maria/env/lib/python3.10/site-packages/sklearn/pipeline.py", line 603, in predict
#     return self.steps[-1][1].predict(Xt, **params)
#   File "/home/tempestade/Documentos/2024-1_victor_hugo_renata_maria/env/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py", line 1602, in _predict
#     y_pred = self._forward_pass_fast(X, check_input=check_input)
#   File "/home/tempestade/Documentos/2024-1_victor_hugo_renata_maria/env/lib/python3.10/site-packages/sklearn/pipeline.py", line 603, in predict
#     return self.steps[-1][1].predict(Xt, **params)
#   File "/home/tempestade/Documentos/2024-1_victor_hugo_renata_maria/env/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py", line 1598, in predict
#     return self._predict(X)
#   File "/home/tempestade/Documentos/2024-1_victor_hugo_renata_maria/beam_problem_1/functions_final_parallel.py", line 543, in _process_design_point
#     depths = np.asarray(carb_model.predict(batch_df), dtype=float).reshape(n_latent_samples, n_grid)
#   File "/home/tempestade/Documentos/2024-1_victor_hugo_renata_maria/env/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py", line 1602, in _predict
#     y_pred = self._forward_pass_fast(X, check_input=check_input)
# KeyboardInterrupt
# Traceback (most recent call last):
# KeyboardInterrupt
# Process ForkPoolWorker-485:
#   File "/usr/lib/python3.10/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/home/tempestade/Documentos/2024-1_victor_hugo_renata_maria/env/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py", line 1598, in predict
#     return self._predict(X)
#   File "/home/tempestade/Documentos/2024-1_victor_hugo_renata_maria/env/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py", line 218, in _forward_pass_fast
#     hidden_activation(activation)
#   File "/home/tempestade/Documentos/2024-1_victor_hugo_renata_maria/env/lib/python3.10/site-packages/sklearn/pipeline.py", line 603, in predict
#     return self.steps[-1][1].predict(Xt, **params)
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.10/multiprocessing/pool.py", line 51, in starmapstar
#     return list(itertools.starmap(args[0], args[1]))
# Traceback (most recent call last):
#   File "/home/tempestade/Documentos/2024-1_victor_hugo_renata_maria/env/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py", line 218, in _forward_pass_fast
#     hidden_activation(activation)
#   File "/home/tempestade/Documentos/2024-1_victor_hugo_renata_maria/env/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py", line 1602, in _predict
#     y_pred = self._forward_pass_fast(X, check_input=check_input)
#   File "/home/tempestade/Documentos/2024-1_victor_hugo_renata_maria/env/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py", line 1598, in predict
#     return self._predict(X)
#   File "/usr/lib/python3.10/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#   File "/home/tempestade/Documentos/2024-1_victor_hugo_renata_maria/env/lib/python3.10/site-packages/sklearn/neural_network/_base.py", line 54, in inplace_relu
#     np.maximum(X, 0, out=X)
#   File "/home/tempestade/Documentos/2024-1_victor_hugo_renata_maria/beam_problem_1/functions_final_parallel.py", line 543, in _process_design_point
#     depths = np.asarray(carb_model.predict(batch_df), dtype=float).reshape(n_latent_samples, n_grid)
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
# KeyboardInterrupt
#   File "/usr/lib/python3.10/multiprocessing/pool.py", line 51, in starmapstar
#     return list(itertools.starmap(args[0], args[1]))
#   File "/home/tempestade/Documentos/2024-1_victor_hugo_renata_maria/env/lib/python3.10/site-packages/sklearn/neural_network/_base.py", line 46, in inplace_relu
#     def inplace_relu(X):
#   File "/home/tempestade/Documentos/2024-1_victor_hugo_renata_maria/env/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py", line 1602, in _predict
#     y_pred = self._forward_pass_fast(X, check_input=check_input)
#   File "/home/tempestade/Documentos/2024-1_victor_hugo_renata_maria/env/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py", line 218, in _forward_pass_fast
#     hidden_activation(activation)
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/tempestade/Documentos/2024-1_victor_hugo_renata_maria/beam_problem_1/functions_final_parallel.py", line 543, in _process_design_point
#     depths = np.asarray(carb_model.predict(batch_df), dtype=float).reshape(n_latent_samples, n_grid)
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/home/tempestade/Documentos/2024-1_victor_hugo_renata_maria/env/lib/python3.10/site-packages/sklearn/utils/extmath.py", line 211, in safe_sparse_dot
#     sparse.issparse(a)
#   File "/home/tempestade/Documentos/2024-1_victor_hugo_renata_maria/env/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py", line 1598, in predict
#     return self._predict(X)
# Process ForkPoolWorker-499:
# Traceback (most recent call last):
# KeyboardInterrupt
# Process ForkPoolWorker-482:
# Process ForkPoolWorker-511:
#   File "/home/tempestade/Documentos/2024-1_victor_hugo_renata_maria/env/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py", line 215, in _forward_pass_fast
#     activation = safe_sparse_dot(activation, self.coefs_[i])
# Process ForkPoolWorker-510:
#   File "/usr/lib/python3.10/multiprocessing/pool.py", line 51, in starmapstar
#     return list(itertools.starmap(args[0], args[1]))
#   File "/home/tempestade/Documentos/2024-1_victor_hugo_renata_maria/env/lib/python3.10/site-packages/sklearn/pipeline.py", line 603, in predict
#     return self.steps[-1][1].predict(Xt, **params)
#   File "/home/tempestade/Documentos/2024-1_victor_hugo_renata_maria/env/lib/python3.10/site-packages/sklearn/pipeline.py", line 603, in predict
#     return self.steps[-1][1].predict(Xt, **params)
# KeyboardInterrupt
#   File "/home/tempestade/Documentos/2024-1_victor_hugo_renata_maria/env/lib/python3.10/site-packages/sklearn/neural_network/_base.py", line 54, in inplace_relu
#     np.maximum(X, 0, out=X)
#   File "/usr/lib/python3.10/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
# Process ForkPoolWorker-484:
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/home/tempestade/Documentos/2024-1_victor_hugo_renata_maria/env/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py", line 1602, in _predict
#     y_pred = self._forward_pass_fast(X, check_input=check_input)
#   File "/home/tempestade/Documentos/2024-1_victor_hugo_renata_maria/beam_problem_1/functions_final_parallel.py", line 543, in _process_design_point
#     depths = np.asarray(carb_model.predict(batch_df), dtype=float).reshape(n_latent_samples, n_grid)
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/tempestade/Documentos/2024-1_victor_hugo_renata_maria/beam_problem_1/functions_final_parallel.py", line 543, in _process_design_point
#     depths = np.asarray(carb_model.predict(batch_df), dtype=float).reshape(n_latent_samples, n_grid)
#   File "/home/tempestade/Documentos/2024-1_victor_hugo_renata_maria/env/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py", line 1598, in predict
#     return self._predict(X)
#   File "/home/tempestade/Documentos/2024-1_victor_hugo_renata_maria/env/lib/python3.10/site-packages/scipy/sparse/_base.py", line 1388, in issparse
#     def issparse(x):
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/tempestade/Documentos/2024-1_victor_hugo_renata_maria/env/lib/python3.10/site-packages/sklearn/pipeline.py", line 603, in predict
#     return self.steps[-1][1].predict(Xt, **params)
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#   File "/home/tempestade/Documentos/2024-1_victor_hugo_renata_maria/env/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py", line 1602, in _predict
#     y_pred = self._forward_pass_fast(X, check_input=check_input)
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.10/multiprocessing/pool.py", line 51, in starmapstar
#     return list(itertools.starmap(args[0], args[1]))
#   File "/home/tempestade/Documentos/2024-1_victor_hugo_renata_maria/beam_problem_1/functions_final_parallel.py", line 543, in _process_design_point
#     depths = np.asarray(carb_model.predict(batch_df), dtype=float).reshape(n_latent_samples, n_grid)
# KeyboardInterrupt
#   File "/usr/lib/python3.10/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#   File "/home/tempestade/Documentos/2024-1_victor_hugo_renata_maria/env/lib/python3.10/site-packages/sklearn/pipeline.py", line 603, in predict
#     return self.steps[-1][1].predict(Xt, **params)
#   File "/usr/lib/python3.10/multiprocessing/pool.py", line 51, in starmapstar
#     return list(itertools.starmap(args[0], args[1]))
#   File "/home/tempestade/Documentos/2024-1_victor_hugo_renata_maria/env/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py", line 215, in _forward_pass_fast
#     activation = safe_sparse_dot(activation, self.coefs_[i])
#   File "/home/tempestade/Documentos/2024-1_victor_hugo_renata_maria/env/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py", line 1598, in predict
#     return self._predict(X)
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/home/tempestade/Documentos/2024-1_victor_hugo_renata_maria/env/lib/python3.10/site-packages/sklearn/pipeline.py", line 603, in predict
#     return self.steps[-1][1].predict(Xt, **params)
#   File "/home/tempestade/Documentos/2024-1_victor_hugo_renata_maria/env/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py", line 215, in _forward_pass_fast
#     activation = safe_sparse_dot(activation, self.coefs_[i])
# Traceback (most recent call last):
#   File "/home/tempestade/Documentos/2024-1_victor_hugo_renata_maria/env/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py", line 1598, in predict
#     return self._predict(X)
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/home/tempestade/Documentos/2024-1_victor_hugo_renata_maria/env/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py", line 1598, in predict
#     return self._predict(X)
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/tempestade/Documentos/2024-1_victor_hugo_renata_maria/env/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py", line 1602, in _predict
#     y_pred = self._forward_pass_fast(X, check_input=check_input)
#   File "/home/tempestade/Documentos/2024-1_victor_hugo_renata_maria/env/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py", line 1602, in _predict
#     y_pred = self._forward_pass_fast(X, check_input=check_input)
#   File "/home/tempestade/Documentos/2024-1_victor_hugo_renata_maria/env/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py", line 1602, in _predict
#     y_pred = self._forward_pass_fast(X, check_input=check_input)
#   File "/home/tempestade/Documentos/2024-1_victor_hugo_renata_maria/env/lib/python3.10/site-packages/sklearn/utils/extmath.py", line 211, in safe_sparse_dot
#     sparse.issparse(a)
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/home/tempestade/Documentos/2024-1_victor_hugo_renata_maria/env/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py", line 215, in _forward_pass_fast
#     activation = safe_sparse_dot(activation, self.coefs_[i])
#   File "/home/tempestade/Documentos/2024-1_victor_hugo_renata_maria/env/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py", line 215, in _forward_pass_fast
#     activation = safe_sparse_dot(activation, self.coefs_[i])
#   File "/home/tempestade/Documentos/2024-1_victor_hugo_renata_maria/env/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py", line 218, in _forward_pass_fast
#     hidden_activation(activation)
#   File "/home/tempestade/Documentos/2024-1_victor_hugo_renata_maria/env/lib/python3.10/site-packages/scipy/sparse/_base.py", line 1388, in issparse
#     def issparse(x):
#   File "/home/tempestade/Documentos/2024-1_victor_hugo_renata_maria/env/lib/python3.10/site-packages/sklearn/utils/extmath.py", line 211, in safe_sparse_dot
#     sparse.issparse(a)
#   File "/home/tempestade/Documentos/2024-1_victor_hugo_renata_maria/env/lib/python3.10/site-packages/sklearn/utils/extmath.py", line 211, in safe_sparse_dot
#     sparse.issparse(a)
#   File "/home/tempestade/Documentos/2024-1_victor_hugo_renata_maria/env/lib/python3.10/site-packages/sklearn/utils/extmath.py", line 211, in safe_sparse_dot
#     sparse.issparse(a)
#   File "/usr/lib/python3.10/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#   File "/usr/lib/python3.10/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/tempestade/Documentos/2024-1_victor_hugo_renata_maria/env/lib/python3.10/site-packages/scipy/sparse/_base.py", line 1388, in issparse
#     def issparse(x):
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/home/tempestade/Documentos/2024-1_victor_hugo_renata_maria/env/lib/python3.10/site-packages/scipy/sparse/_base.py", line 1388, in issparse
#     def issparse(x):
# KeyboardInterrupt
#   File "/usr/lib/python3.10/multiprocessing/pool.py", line 51, in starmapstar
#     return list(itertools.starmap(args[0], args[1]))
#   File "/usr/lib/python3.10/multiprocessing/pool.py", line 51, in starmapstar
#     return list(itertools.starmap(args[0], args[1]))
#   File "/usr/lib/python3.10/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#   File "/home/tempestade/Documentos/2024-1_victor_hugo_renata_maria/beam_problem_1/functions_final_parallel.py", line 543, in _process_design_point
#     depths = np.asarray(carb_model.predict(batch_df), dtype=float).reshape(n_latent_samples, n_grid)
#   File "/home/tempestade/Documentos/2024-1_victor_hugo_renata_maria/beam_problem_1/functions_final_parallel.py", line 543, in _process_design_point
#     depths = np.asarray(carb_model.predict(batch_df), dtype=float).reshape(n_latent_samples, n_grid)
#   File "/home/tempestade/Documentos/2024-1_victor_hugo_renata_maria/env/lib/python3.10/site-packages/sklearn/neural_network/_base.py", line 54, in inplace_relu
#     np.maximum(X, 0, out=X)
#   File "/usr/lib/python3.10/multiprocessing/pool.py", line 51, in starmapstar
#     return list(itertools.starmap(args[0], args[1]))
#   File "/home/tempestade/Documentos/2024-1_victor_hugo_renata_maria/env/lib/python3.10/site-packages/sklearn/pipeline.py", line 603, in predict
#     return self.steps[-1][1].predict(Xt, **params)
#   File "/home/tempestade/Documentos/2024-1_victor_hugo_renata_maria/env/lib/python3.10/site-packages/sklearn/pipeline.py", line 603, in predict
#     return self.steps[-1][1].predict(Xt, **params)
#   File "/home/tempestade/Documentos/2024-1_victor_hugo_renata_maria/beam_problem_1/functions_final_parallel.py", line 543, in _process_design_point
#     depths = np.asarray(carb_model.predict(batch_df), dtype=float).reshape(n_latent_samples, n_grid)
# KeyboardInterrupt
#   File "/home/tempestade/Documentos/2024-1_victor_hugo_renata_maria/env/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py", line 1598, in predict
#     return self._predict(X)
#   File "/home/tempestade/Documentos/2024-1_victor_hugo_renata_maria/env/lib/python3.10/site-packages/scipy/sparse/_base.py", line 1388, in issparse
#     def issparse(x):
#   File "/home/tempestade/Documentos/2024-1_victor_hugo_renata_maria/env/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py", line 1602, in _predict
#     y_pred = self._forward_pass_fast(X, check_input=check_input)
#   File "/home/tempestade/Documentos/2024-1_victor_hugo_renata_maria/env/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py", line 215, in _forward_pass_fast
#     activation = safe_sparse_dot(activation, self.coefs_[i])
#   File "/home/tempestade/Documentos/2024-1_victor_hugo_renata_maria/env/lib/python3.10/site-packages/sklearn/utils/extmath.py", line 211, in safe_sparse_dot
#     sparse.issparse(a)
#   File "/home/tempestade/Documentos/2024-1_victor_hugo_renata_maria/env/lib/python3.10/site-packages/scipy/sparse/_base.py", line 1388, in issparse
#     def issparse(x):
# KeyboardInterrupt
#   File "/home/tempestade/Documentos/2024-1_victor_hugo_renata_maria/env/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py", line 1598, in predict
#     return self._predict(X)
#   File "/home/tempestade/Documentos/2024-1_victor_hugo_renata_maria/env/lib/python3.10/site-packages/sklearn/pipeline.py", line 603, in predict
#     return self.steps[-1][1].predict(Xt, **params)
#   File "/home/tempestade/Documentos/2024-1_victor_hugo_renata_maria/env/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py", line 1602, in _predict
#     y_pred = self._forward_pass_fast(X, check_input=check_input)
#   File "/home/tempestade/Documentos/2024-1_victor_hugo_renata_maria/env/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py", line 1598, in predict
#     return self._predict(X)
# KeyboardInterrupt
#   File "/home/tempestade/Documentos/2024-1_victor_hugo_renata_maria/env/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py", line 215, in _forward_pass_fast
#     activation = safe_sparse_dot(activation, self.coefs_[i])
#   File "/home/tempestade/Documentos/2024-1_victor_hugo_renata_maria/env/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py", line 1602, in _predict
#     y_pred = self._forward_pass_fast(X, check_input=check_input)
# Process ForkPoolWorker-508:
#   File "/home/tempestade/Documentos/2024-1_victor_hugo_renata_maria/env/lib/python3.10/site-packages/sklearn/utils/extmath.py", line 211, in safe_sparse_dot
#     sparse.issparse(a)
# Process ForkPoolWorker-512:
# Process ForkPoolWorker-498:
# Process ForkPoolWorker-504:
#   File "/home/tempestade/Documentos/2024-1_victor_hugo_renata_maria/env/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py", line 215, in _forward_pass_fast
#     activation = safe_sparse_dot(activation, self.coefs_[i])
# Process ForkPoolWorker-497:
# Process ForkPoolWorker-486:
#   File "/home/tempestade/Documentos/2024-1_victor_hugo_renata_maria/env/lib/python3.10/site-packages/sklearn/utils/extmath.py", line 211, in safe_sparse_dot
#     sparse.issparse(a)
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/home/tempestade/Documentos/2024-1_victor_hugo_renata_maria/env/lib/python3.10/site-packages/scipy/sparse/_base.py", line 1388, in issparse
#     def issparse(x):
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/home/tempestade/Documentos/2024-1_victor_hugo_renata_maria/env/lib/python3.10/site-packages/scipy/sparse/_base.py", line 1388, in issparse
#     def issparse(x):
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
# KeyboardInterrupt
#   File "/usr/lib/python3.10/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
# KeyboardInterrupt
#   File "/usr/lib/python3.10/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.10/multiprocessing/pool.py", line 51, in starmapstar
#     return list(itertools.starmap(args[0], args[1]))
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#   File "/usr/lib/python3.10/multiprocessing/pool.py", line 51, in starmapstar
#     return list(itertools.starmap(args[0], args[1]))
#   File "/usr/lib/python3.10/multiprocessing/pool.py", line 51, in starmapstar
#     return list(itertools.starmap(args[0], args[1]))
#   File "/home/tempestade/Documentos/2024-1_victor_hugo_renata_maria/beam_problem_1/functions_final_parallel.py", line 543, in _process_design_point
#     depths = np.asarray(carb_model.predict(batch_df), dtype=float).reshape(n_latent_samples, n_grid)
#   File "/home/tempestade/Documentos/2024-1_victor_hugo_renata_maria/beam_problem_1/functions_final_parallel.py", line 543, in _process_design_point
#     depths = np.asarray(carb_model.predict(batch_df), dtype=float).reshape(n_latent_samples, n_grid)
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/home/tempestade/Documentos/2024-1_victor_hugo_renata_maria/env/lib/python3.10/site-packages/sklearn/pipeline.py", line 603, in predict
#     return self.steps[-1][1].predict(Xt, **params)
# Traceback (most recent call last):
#   File "/home/tempestade/Documentos/2024-1_victor_hugo_renata_maria/env/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py", line 1598, in predict
#     return self._predict(X)
#   File "/home/tempestade/Documentos/2024-1_victor_hugo_renata_maria/env/lib/python3.10/site-packages/sklearn/pipeline.py", line 603, in predict
#     return self.steps[-1][1].predict(Xt, **params)
#   File "/home/tempestade/Documentos/2024-1_victor_hugo_renata_maria/beam_problem_1/functions_final_parallel.py", line 543, in _process_design_point
#     depths = np.asarray(carb_model.predict(batch_df), dtype=float).reshape(n_latent_samples, n_grid)
#   File "/home/tempestade/Documentos/2024-1_victor_hugo_renata_maria/env/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py", line 1602, in _predict
#     y_pred = self._forward_pass_fast(X, check_input=check_input)
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/tempestade/Documentos/2024-1_victor_hugo_renata_maria/env/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py", line 218, in _forward_pass_fast
#     hidden_activation(activation)
#   File "/home/tempestade/Documentos/2024-1_victor_hugo_renata_maria/env/lib/python3.10/site-packages/sklearn/pipeline.py", line 603, in predict
#     return self.steps[-1][1].predict(Xt, **params)
#   File "/home/tempestade/Documentos/2024-1_victor_hugo_renata_maria/env/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py", line 1598, in predict
#     return self._predict(X)
#   File "/usr/lib/python3.10/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#   File "/home/tempestade/Documentos/2024-1_victor_hugo_renata_maria/env/lib/python3.10/site-packages/sklearn/neural_network/_base.py", line 54, in inplace_relu
#     np.maximum(X, 0, out=X)
#   File "/home/tempestade/Documentos/2024-1_victor_hugo_renata_maria/env/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py", line 1602, in _predict
#     y_pred = self._forward_pass_fast(X, check_input=check_input)
#   File "/usr/lib/python3.10/multiprocessing/pool.py", line 51, in starmapstar
#     return list(itertools.starmap(args[0], args[1]))
# KeyboardInterrupt
#   File "/home/tempestade/Documentos/2024-1_victor_hugo_renata_maria/env/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py", line 218, in _forward_pass_fast
#     hidden_activation(activation)
#   File "/home/tempestade/Documentos/2024-1_victor_hugo_renata_maria/beam_problem_1/functions_final_parallel.py", line 543, in _process_design_point
#     depths = np.asarray(carb_model.predict(batch_df), dtype=float).reshape(n_latent_samples, n_grid)
#   File "/home/tempestade/Documentos/2024-1_victor_hugo_renata_maria/env/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py", line 1598, in predict
#     return self._predict(X)
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/home/tempestade/Documentos/2024-1_victor_hugo_renata_maria/env/lib/python3.10/site-packages/sklearn/neural_network/_base.py", line 46, in inplace_relu
#     def inplace_relu(X):
#   File "/home/tempestade/Documentos/2024-1_victor_hugo_renata_maria/env/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py", line 1602, in _predict
#     y_pred = self._forward_pass_fast(X, check_input=check_input)
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
# KeyboardInterrupt
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/tempestade/Documentos/2024-1_victor_hugo_renata_maria/env/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py", line 215, in _forward_pass_fast
#     activation = safe_sparse_dot(activation, self.coefs_[i])
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.10/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#   File "/home/tempestade/Documentos/2024-1_victor_hugo_renata_maria/env/lib/python3.10/site-packages/sklearn/utils/extmath.py", line 211, in safe_sparse_dot
#     sparse.issparse(a)
#   File "/usr/lib/python3.10/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#   File "/usr/lib/python3.10/multiprocessing/pool.py", line 51, in starmapstar
#     return list(itertools.starmap(args[0], args[1]))
#   File "/home/tempestade/Documentos/2024-1_victor_hugo_renata_maria/env/lib/python3.10/site-packages/scipy/sparse/_base.py", line 1388, in issparse
#     def issparse(x):
#   File "/home/tempestade/Documentos/2024-1_victor_hugo_renata_maria/env/lib/python3.10/site-packages/sklearn/pipeline.py", line 603, in predict
#     return self.steps[-1][1].predict(Xt, **params)
#   File "/home/tempestade/Documentos/2024-1_victor_hugo_renata_maria/beam_problem_1/functions_final_parallel.py", line 543, in _process_design_point
#     depths = np.asarray(carb_model.predict(batch_df), dtype=float).reshape(n_latent_samples, n_grid)
#   File "/home/tempestade/Documentos/2024-1_victor_hugo_renata_maria/env/lib/python3.10/site-packages/sklearn/pipeline.py", line 603, in predict
#     return self.steps[-1][1].predict(Xt, **params)
#   File "/home/tempestade/Documentos/2024-1_victor_hugo_renata_maria/env/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py", line 1598, in predict
#     return self._predict(X)
# KeyboardInterrupt
#   File "/usr/lib/python3.10/multiprocessing/pool.py", line 51, in starmapstar
#     return list(itertools.starmap(args[0], args[1]))
#   File "/home/tempestade/Documentos/2024-1_victor_hugo_renata_maria/env/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py", line 1602, in _predict
#     y_pred = self._forward_pass_fast(X, check_input=check_input)
#   File "/home/tempestade/Documentos/2024-1_victor_hugo_renata_maria/env/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py", line 215, in _forward_pass_fast
#     activation = safe_sparse_dot(activation, self.coefs_[i])
#   File "/home/tempestade/Documentos/2024-1_victor_hugo_renata_maria/env/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py", line 1598, in predict
#     return self._predict(X)
#   File "/home/tempestade/Documentos/2024-1_victor_hugo_renata_maria/env/lib/python3.10/site-packages/sklearn/utils/extmath.py", line 211, in safe_sparse_dot
#     sparse.issparse(a)
#   File "/home/tempestade/Documentos/2024-1_victor_hugo_renata_maria/env/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py", line 1602, in _predict
#     y_pred = self._forward_pass_fast(X, check_input=check_input)
#   File "/home/tempestade/Documentos/2024-1_victor_hugo_renata_maria/env/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py", line 215, in _forward_pass_fast
#     activation = safe_sparse_dot(activation, self.coefs_[i])
#   File "/home/tempestade/Documentos/2024-1_victor_hugo_renata_maria/beam_problem_1/functions_final_parallel.py", line 543, in _process_design_point
#     depths = np.asarray(carb_model.predict(batch_df), dtype=float).reshape(n_latent_samples, n_grid)
#   File "/home/tempestade/Documentos/2024-1_victor_hugo_renata_maria/env/lib/python3.10/site-packages/scipy/sparse/_base.py", line 1388, in issparse
#     def issparse(x):
#   File "/home/tempestade/Documentos/2024-1_victor_hugo_renata_maria/env/lib/python3.10/site-packages/sklearn/pipeline.py", line 603, in predict
#     return self.steps[-1][1].predict(Xt, **params)
# KeyboardInterrupt
#   File "/home/tempestade/Documentos/2024-1_victor_hugo_renata_maria/env/lib/python3.10/site-packages/sklearn/utils/extmath.py", line 211, in safe_sparse_dot
#     sparse.issparse(a)
#   File "/home/tempestade/Documentos/2024-1_victor_hugo_renata_maria/env/lib/python3.10/site-packages/scipy/sparse/_base.py", line 1388, in issparse
#     def issparse(x):
# KeyboardInterrupt
#   File "/home/tempestade/Documentos/2024-1_victor_hugo_renata_maria/env/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py", line 1598, in predict
#     return self._predict(X)
#   File "/home/tempestade/Documentos/2024-1_victor_hugo_renata_maria/env/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py", line 1602, in _predict
#     y_pred = self._forward_pass_fast(X, check_input=check_input)
#   File "/home/tempestade/Documentos/2024-1_victor_hugo_renata_maria/env/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py", line 215, in _forward_pass_fast
#     activation = safe_sparse_dot(activation, self.coefs_[i])
#   File "/home/tempestade/Documentos/2024-1_victor_hugo_renata_maria/env/lib/python3.10/site-packages/sklearn/utils/extmath.py", line 211, in safe_sparse_dot
#     sparse.issparse(a)
#   File "/home/tempestade/Documentos/2024-1_victor_hugo_renata_maria/env/lib/python3.10/site-packages/scipy/sparse/_base.py", line 1388, in issparse
#     def issparse(x):
# KeyboardInterrupt
