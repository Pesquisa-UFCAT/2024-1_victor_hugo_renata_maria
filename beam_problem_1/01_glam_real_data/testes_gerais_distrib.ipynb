# %%
import dill 
filename_stats = f'pce_validation_stats_0.0_install_1990_cement_3_exposure_2.pkl'
with open(filename_stats, 'rb') as f:
    file_loaded = dill.load(f)
file_loaded
# Out:
#      MSE λ1   MSE λ2    MSE λ3    MSE λ4     R² λ1     R² λ2     R² λ3  \
# 0  0.041936  0.00228  0.000155  0.000174  0.968334 -4.626177 -1.810411
#
#       R² λ4
# 0 -3.723842

# %%
import numpy as np
n_latent_samples = 2000
cov_mean   = 1.0
cov_cov    = 0.02
sigma_cov  = np.sqrt(np.log(1 + cov_cov**2))
mu_cov     = np.log(cov_mean) - sigma_cov**2 / 2
cov_latent = np.random.lognormal(mean=mu_cov, sigma=sigma_cov, size=n_latent_samples)
cov_latent
# Out:
# array([0.98524474, 1.00877997, 0.98169156, ..., 1.00533626, 0.99430213,
#        1.02517298])

# %%
import matplotlib.pyplot as plt
plt.hist(cov_latent, bins=20, density=True)
# Out:
# (array([ 0.46637666,  0.15545889,  1.0882122 ,  3.2646366 ,  5.51879044,
#          7.07337929, 11.34849865, 13.9912997 , 16.7118302 , 21.14240844,
#         18.11096017, 18.88825459, 14.92405301,  9.71618035,  6.91792041,
#          2.64280105,  2.40961273,  0.46637666,  0.31091777,  0.31091777]),
#  array([0.93752808, 0.94396065, 0.95039322, 0.95682579, 0.96325836,
#         0.96969093, 0.9761235 , 0.98255607, 0.98898864, 0.9954212 ,
#         1.00185377, 1.00828634, 1.01471891, 1.02115148, 1.02758405,
#         1.03401662, 1.04044919, 1.04688176, 1.05331432, 1.05974689,
#         1.06617946]),
#  <BarContainer object of 20 artists>)
