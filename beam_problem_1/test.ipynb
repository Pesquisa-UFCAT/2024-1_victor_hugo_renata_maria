# %%
import functions as fct
import numpy as np

# %%
y, df = fct.state_limit_function_time([{}], [{}], [{'q_k [kN/m]': 10}], [{'temp [°C]': 30, 'rh [%]': 50}], time=0.0, n_latent_samples=20)

# %%
y
# Out:
# array(1.)

# %%
df[0]
# Out:
# Empty DataFrame
# Columns: [z1, z2, z3]
# Index: []
