# %% [markdown]
# # Bibliotecas

# %%
from obj import *
import scipy as sc

# %% [markdown]
# # Testes

# %% [markdown]
# ## Linha neutra

# %%
f_ck = 25E3
f_yk = 500E3
b_w = 0.20
h = 0.50
d = 0.49
a_st = 0.002
e_s = 200E6
gamma_c = 1.4
gamma_s = 1.15
args = (f_ck, f_yk, b_w, d, a_st, e_s, gamma_c, gamma_s)
resultado = sc.optimize.root_scalar(lambda beta: f_alpha(beta, args), bracket=(0.00001, d/h), method='bisect')
beta = resultado.root
print(f'Beta: {beta:.4f}')
x = beta * d
print(f'x: {x:.4f} m')
residuo = f_alpha(beta, args)
print(f'Residuo: {residuo:.4f}')
# Out:
# Beta: 0.7307
# x: 0.3581 m
# Residuo: -0.0000

# %% [markdown]
# ## Momento resistente

# %%
m_rd = momento_limite_armadura_simples(a_st: float, b_w: float, h: float, relacao_h_d: float, f_ck: float, f_yk: float, e_s: float, gamma_c: float = 1.4, gamma_s: float = 1.15)
m_rd

# %% [markdown]
# ## Profundidade de carbonatação

# %%
k_c = 
k_fc = 
f_ck = 
i = 
ad = 
co2 = 
k_co2 =
ur = 
k_rh =
k_ce =

y_carb = profundidade_carbonatacao_possan(k_c, k_fc,  f_ck/1000, i, ad, k_ad, co2, k_co2, ur/100, k_rh, k_ce)
y_carb

# %% [markdown]
# ##
