# %% [markdown]
# # Bibliotecas

# %%
from obj import *
import scipy as sc

# %% [markdown]
# # Testes

# %% [markdown]
# ## Linha neutra

# %%
f_ck = 20E3
f_yk = 500E3
b_w = 0.20
h = 0.50
d = 0.47
a_st = 8.10E-4
e_s = 200E6
gamma_c = 1.4
gamma_s = 1.15
args = (f_ck, f_yk, b_w, d, a_st, e_s, gamma_c, gamma_s)
resultado = sc.optimize.root_scalar(lambda beta: f_alpha(beta, args), bracket=(0.00001, d/h), method='bisect')
beta = resultado.root
print(f'Beta: {beta:.4f}')
x = beta * d
print(f'x: {x:.4f} m')
residuo = f_alpha(beta, args)
print(f'Residuo: {residuo:.4f}')
# Out:
# Beta: 0.3857
# x: 0.1813 m
# Residuo: 0.0000

# %%
m_rd = momento_limite_armadura_simples(a_st, b_w, h, d/h, f_ck, f_yk, e_s)
m_rd
# Out:
# 139.98687868369953

# %%
#1

f_ck = 20E3
f_yk = 500E3
b_w = 0.20
h = 0.50
d = 0.475
a_st = 0.000810
e_s = 200E6
gamma_c = 1.4
gamma_s = 1.15
args = (f_ck, f_yk, b_w, d, a_st, e_s, gamma_c, gamma_s)
resultado = sc.optimize.root_scalar(lambda beta: f_alpha(beta, args), bracket=(0.00001, d/h), method='bisect')
beta = resultado.root
print(f'Beta: {beta:.4f}')
x = beta * d
print(f'x: {x:.4f} m')
residuo = f_alpha(beta, args)
print(f'Residuo: {residuo:.4f}')
# Out:
# Beta: 0.3816
# x: 0.1813 m
# Residuo: 0.0000

# %%
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 m_rd = momento_limite_armadura_simples(a_st, b_w, h, d, f_ck, f_yk, e_s, gamma_c = 1.4, gamma_s = 1.15)
#       2 m_rd
#
# File ~/Documents/ic_victor/obj.py:106, in momento_limite_armadura_simples(a_st, b_w, h, relacao_h_d, f_ck, f_yk, e_s, gamma_c, gamma_s)
#     104 # Encontrar equilíbrio de forças normais
#     105 args = (f_ck, f_yk, b_w, d, a_st, e_s, gamma_c, gamma_s)
# --> 106 resultado = sc.optimize.root_scalar(lambda beta: f_alpha(beta, args), bracket=(0.00001, d/h), method='bisect')
#     108 # Profundidade da linha neutra
#     109 x = resultado.root * d
#
# File ~/Documents/ic_victor/env/lib/python3.12/site-packages/scipy/optimize/_root_scalar.py:286, in root_scalar(f, args, method, bracket, fprime, fprime2, x0, x1, xtol, rtol, maxiter, options)
#     284 a, b = bracket[:2]
#     285 try:
# --> 286     r, sol = methodc(f, a, b, args=args, **kwargs)
#     287 except ValueError as e:
#     288     # gh-17622 fixed some bugs in low-level solvers by raising an error
#     289     # (rather than returning incorrect results) when the callable
#     290     # returns a NaN. It did so by wrapping the callable rather than
#     291     # modifying compiled code, so the iteration count is not available.
#     292     if hasattr(e, "_x"):
#
# File ~/Documents/ic_victor/env/lib/python3.12/site-packages/scipy/optimize/_zeros_py.py:595, in bisect(f, a, b, args, xtol, rtol, maxiter, full_output, disp)
#     593     raise ValueError(f"rtol too small ({rtol:g} < {_rtol:g})")
#     594 f = _wrap_nan_raise(f)
# --> 595 r = _zeros._bisect(f, a, b, xtol, rtol, maxiter, args, full_output, disp)
#     596 return results_c(full_output, r, "bisect")
#
# ValueError: f(a) and f(b) must have different signs

# %%
#2

f_ck = 20E3
f_yk = 500E3
b_w = 0.20
h = 0.50
d = 0.465
a_st = 0.0008
e_s = 200E6
gamma_c = 1.4
gamma_s = 1.15
args = (f_ck, f_yk, b_w, d, a_st, e_s, gamma_c, gamma_s)
resultado = sc.optimize.root_scalar(lambda beta: f_alpha(beta, args), bracket=(0.00001, d/h), method='bisect')
beta = resultado.root
print(f'Beta: {beta:.4f}')
x = beta * d
print(f'x: {x:.4f} m')
residuo = f_alpha(beta, args)
print(f'Residuo: {residuo:.4f}')
# Out:
# Beta: 0.3850
# x: 0.1790 m
# Residuo: -0.0000

# %%
m_rd = momento_limite_armadura_simples(a_st, b_w, h, d, f_ck, f_yk, e_s, gamma_c = 1.4, gamma_s = 1.15)
m_rd
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 m_rd = momento_limite_armadura_simples(a_st, b_w, h, d, f_ck, f_yk, e_s, gamma_c = 1.4, gamma_s = 1.15)
#       2 m_rd
#
# File d:\Documentos\ic_victor\obj.py:106, in momento_limite_armadura_simples(a_st, b_w, h, relacao_h_d, f_ck, f_yk, e_s, gamma_c, gamma_s)
#     104 # Encontrar equilíbrio de forças normais
#     105 args = (f_ck, f_yk, b_w, d, a_st, e_s, gamma_c, gamma_s)
# --> 106 resultado = sc.optimize.root_scalar(lambda beta: f_alpha(beta, args), bracket=(0.00001, d/h), method='bisect')
#     108 # Profundidade da linha neutra
#     109 x = resultado.root * d
#
# File d:\Documentos\ic_victor\env\Lib\site-packages\scipy\optimize\_root_scalar.py:286, in root_scalar(f, args, method, bracket, fprime, fprime2, x0, x1, xtol, rtol, maxiter, options)
#     284 a, b = bracket[:2]
#     285 try:
# --> 286     r, sol = methodc(f, a, b, args=args, **kwargs)
#     287 except ValueError as e:
#     288     # gh-17622 fixed some bugs in low-level solvers by raising an error
#     289     # (rather than returning incorrect results) when the callable
#     290     # returns a NaN. It did so by wrapping the callable rather than
#     291     # modifying compiled code, so the iteration count is not available.
#     292     if hasattr(e, "_x"):
#
# File d:\Documentos\ic_victor\env\Lib\site-packages\scipy\optimize\_zeros_py.py:595, in bisect(f, a, b, args, xtol, rtol, maxiter, full_output, disp)
#     593     raise ValueError(f"rtol too small ({rtol:g} < {_rtol:g})")
#     594 f = _wrap_nan_raise(f)
# --> 595 r = _zeros._bisect(f, a, b, xtol, rtol, maxiter, args, full_output, disp)
#     596 return results_c(full_output, r, "bisect")
#
# ValueError: f(a) and f(b) must have different signs

# %% [markdown]
# ## Momento resistente

# %% [markdown]
# ## Profundidade de carbonatação

# %%
k_c = 
k_fc = 
f_ck = 
i = 
ad = 
co2 = 
k_co2 =
ur = 
k_rh =
k_ce =

y_carb = profundidade_carbonatacao_possan(k_c, k_fc,  f_ck/1000, i, ad, k_ad, co2, k_co2, ur/100, k_rh, k_ce)
y_carb

# %% [markdown]
# ##
