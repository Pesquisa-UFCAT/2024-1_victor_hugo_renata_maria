# %%
import pickle
with open('pce_metamodel.pkl', 'rb') as f:

    pce_metamodel = pickle.load(f)
# Out:
# /home/joao/miniconda3/envs/uqpy_env/lib/python3.11/site-packages/UQpy/__init__.py:6: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   import pkg_resources

# %%
print(pce_metamodel)
