# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("Default Dataset.csv", sep=",")
df['k'] = df['c'] / np.sqrt(df['time'])
df.describe()
# Out:
#              time          c          k
# count   28.000000  28.000000  27.000000
# mean    42.376831  19.283112   3.271587
# std     33.978006  10.592420   0.319960
# min      0.000000   0.000000   1.738312
# 25%     11.192047  10.666668   3.309055
# 50%     37.500363  20.637769   3.365091
# 75%     70.467963  28.361966   3.390560
# max    100.016607  33.703827   3.422954
