# %% [markdown]
# # Libraries

# %%
import sys
from pathlib import Path
project_root = Path.cwd().parent
sys.path.insert(0, str(project_root))
from functions import *
from UQpy.distributions import Normal, JointIndependent
import matplotlib as mpl
mpl.rcParams.update({
                        'font.family': 'serif',
                        'mathtext.fontset': 'cm',
                        'axes.unicode_minus': False
                    })
import seaborn as sns
import numpy as np
# Out:
# /home/wmpjrufg/Documents/2024-1_victor_hugo_renata_maria/myenv/lib/python3.12/site-packages/UQpy/__init__.py:6: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   import pkg_resources

# %% [markdown]
# # Dataset

# %% [markdown]
# ### General data

# %%
n_latent_samples = 1000
n_samples = 10
r   = Normal(loc = 5., scale=0.8)
s   = Normal(loc = 2., scale=0.6)

# %% [markdown]
# ### State limit function

# %%
step_time = 0.0
divs = 10

# %%
joint = JointIndependent(marginals=[r, s])
x_val = joint.rvs(n_samples)
submatrices = np.array_split(x_val, divs)
df, glam_data = g_toy_problem_parallel_with_multiprocessing(submatrices, n_latent_samples, t=step_time)
glam_data
# Out:
#           r         s  lambda 1  lambda 2  lambda 3  lambda 4
# 0  3.687266  1.555733  2.137637  7.744044  0.125828  0.222962
# 1  4.799304  2.104926  2.702856  5.787338  0.125067  0.225264
# 2  5.862357  2.391299  3.480206  4.987472  0.126493  0.220831
# 3  3.942987  1.217915  2.728440  8.856354  0.131669  0.199652
# 4  5.000471  1.673540  3.332143  6.657349  0.130221  0.206266
# 5  6.162274  0.960683  5.200694  7.503009  0.143180  0.149823
# 6  3.941094  2.068709  1.881504  6.158893  0.121439  0.233889
# 7  3.712741  2.264190  1.459001  5.798269  0.118546  0.238788
# 8  7.170326  0.637238  6.530395  7.085192  0.147892  0.129608
# 9  5.996257  2.084450  3.918620  5.422071  0.129527  0.209288

# %%
glam_data.describe()
# Out:
#                r          s   lambda 1   lambda 2   lambda 3   lambda 4
# count  10.000000  10.000000  10.000000  10.000000  10.000000  10.000000
# mean    5.027508   1.695869   3.337150   6.599999   0.129986   0.203637
# std     1.222428   0.593831   1.559424   1.199056   0.009162   0.036084
# min     3.687266   0.637238   1.459001   4.987472   0.118546   0.129608
# 25%     3.941567   1.302369   2.278942   5.790070   0.125257   0.201305
# 50%     4.899887   1.871125   3.030292   6.408121   0.128010   0.215059
# 75%     5.962782   2.099807   3.809016   7.398555   0.131307   0.224689
# max     7.170326   2.391299   6.530395   8.856354   0.147892   0.238788

# %% [markdown]
# # Charts

# %% [markdown]
# ### English version

# %% [markdown]
# #### $\lambda _1$

# %%
### Figure name and DPI
dpi = 600                                                   # Change as you wish
name = 'lambda 1'           # Change as you wish

### Chart dimensions (in centimeters)
b_cm = 12                                                   # Change as you wish
h_cm = 8                                                    # Change as you wish
inches_to_cm = 1 / 2.54
b_input = b_cm * inches_to_cm
h_input = h_cm * inches_to_cm

### Axis and labels (For LateX font format use the dollar sign $)
label_x = 'Resistance ($R$)'                                # Change as you wish
label_y = 'Load ($S$)'                                      # Change as you wish
label_cmap = '$\lambda _1$'                                 # Change as you wish
size_label = 13                                             # Change as you wish
color_label = 'black'                                       # or hexadecimal. Change as you wish
size_axis = 13                                              # Change as you wish
color_axis = 'black'                                        # or hexadecimal. Change as you wish

### Scatter
cmap_type = 'seismic'                                       # Change as you wish. Check matplotlib colormaps documentation: https://matplotlib.org/stable/users/explain/colors/colormaps.html
size_scatter = 25                                           # Change as you wish

### Grid
on_or_off = True
line_width_grid = 0.5                                       # Change as you wish
alpha_grid = 0.3                                            # Change as you wish
style_grid = '-'                                            # Change as you wish
color_grid = 'gray'                                         # or hexadecimal. Change as you wish

### Figure
fig, ax = plt.subplots(figsize=(b_input, h_input))
ax.tick_params(axis='both', which='major', labelsize=size_axis, colors=color_axis)
ax.set_xlabel(label_x, fontsize=size_label, color=color_label)
ax.set_ylabel(label_y, fontsize=size_label, color=color_label)

### Title. Do you need a title? Use the cell bellow:
# ax.set_title('Sine Wave Plot', fontsize=16)

### Config grid
plt.grid(on_or_off, which='both', linestyle=style_grid, linewidth=line_width_grid, color=color_grid, alpha=alpha_grid)

### Plot data
sc = ax.scatter(glam_data['r'], glam_data['s'], c=glam_data[name], cmap=cmap_type, s=size_scatter)
cbar = fig.colorbar(sc, ax=ax)
cbar.set_label(label_cmap, size=size_label, color=color_label)
cbar.ax.tick_params(labelsize=size_axis)

### Save. Do you need save? Use the cell bellow:
fig.savefig(f'z_glam_from_real_data_{name}_{int(step_time)}_en.png', dpi=dpi, bbox_inches='tight')
plt.show()

# %% [markdown]
# #### $\lambda _2$

# %%
### Figure name and DPI
dpi = 600                                                   # Change as you wish
name = 'lambda 2'           # Change as you wish

### Chart dimensions (in centimeters)
b_cm = 12                                                   # Change as you wish
h_cm = 8                                                    # Change as you wish
inches_to_cm = 1 / 2.54
b_input = b_cm * inches_to_cm
h_input = h_cm * inches_to_cm

### Axis and labels (For LateX font format use the dollar sign $)
label_x = 'Resistance ($R$)'                             # Change as you wish
label_y = 'Load ($S$)'                                 # Change as you wish
label_cmap = '$\lambda _2$'                             # Change as you wish
size_label = 13                                             # Change as you wish
color_label = 'black'                                        # or hexadecimal. Change as you wish
size_axis = 13                                              # Change as you wish
color_axis = 'black'                                          # or hexadecimal. Change as you wish

### Scatter
cmap_type = 'seismic'                                          # Change as you wish. Check matplotlib colormaps documentation: https://matplotlib.org/stable/users/explain/colors/colormaps.html
size_scatter = 25                                           # Change as you wish

### Grid
on_or_off = True
line_width_grid = 0.5                                       # Change as you wish
alpha_grid = 0.3                                            # Change as you wish
style_grid = '-'                                            # Change as you wish
color_grid = 'gray'                                         # or hexadecimal. Change as you wish

### Figure
fig, ax = plt.subplots(figsize=(b_input, h_input))
ax.tick_params(axis='both', which='major', labelsize=size_axis, colors=color_axis)
ax.set_xlabel(label_x, fontsize=size_label, color=color_label)
ax.set_ylabel(label_y, fontsize=size_label, color=color_label)

### Title. Do you need a title? Use the cell bellow:
# ax.set_title('Sine Wave Plot', fontsize=16)

### Config grid
plt.grid(on_or_off, which='both', linestyle=style_grid, linewidth=line_width_grid, color=color_grid, alpha=alpha_grid)

### Plot data
sc = ax.scatter(glam_data['r'], glam_data['s'], c=glam_data[name], cmap=cmap_type, s=size_scatter)
cbar = fig.colorbar(sc, ax=ax)
cbar.set_label(label_cmap, size=size_label, color=color_label)
cbar.ax.tick_params(labelsize=size_axis)

### Save. Do you need save? Use the cell bellow:
fig.savefig(f'z_glam_from_real_data_{name}_en.png', dpi=dpi, bbox_inches='tight')
plt.show()

# %% [markdown]
# #### $\lambda _3$

# %%
### Figure name and DPI
dpi = 600                                                   # Change as you wish
name = 'lambda 3'           # Change as you wish

### Chart dimensions (in centimeters)
b_cm = 12                                                   # Change as you wish
h_cm = 8                                                    # Change as you wish
inches_to_cm = 1 / 2.54
b_input = b_cm * inches_to_cm
h_input = h_cm * inches_to_cm

### Axis and labels (For LateX font format use the dollar sign $)
label_x = 'Resistance ($R$)'                             # Change as you wish
label_y = 'Load ($S$)'                                 # Change as you wish
label_cmap = '$\lambda _3$'                             # Change as you wish
size_label = 13                                             # Change as you wish
color_label = 'black'                                        # or hexadecimal. Change as you wish
size_axis = 13                                              # Change as you wish
color_axis = 'black'                                          # or hexadecimal. Change as you wish

### Scatter
cmap_type = 'seismic'                                          # Change as you wish. Check matplotlib colormaps documentation: https://matplotlib.org/stable/users/explain/colors/colormaps.html
size_scatter = 25                                           # Change as you wish

### Grid
on_or_off = True
line_width_grid = 0.5                                       # Change as you wish
alpha_grid = 0.3                                            # Change as you wish
style_grid = '-'                                            # Change as you wish
color_grid = 'gray'                                         # or hexadecimal. Change as you wish

### Figure
fig, ax = plt.subplots(figsize=(b_input, h_input))
ax.tick_params(axis='both', which='major', labelsize=size_axis, colors=color_axis)
ax.set_xlabel(label_x, fontsize=size_label, color=color_label)
ax.set_ylabel(label_y, fontsize=size_label, color=color_label)

### Title. Do you need a title? Use the cell bellow:
# ax.set_title('Sine Wave Plot', fontsize=16)

### Config grid
plt.grid(on_or_off, which='both', linestyle=style_grid, linewidth=line_width_grid, color=color_grid, alpha=alpha_grid)

### Plot data
sc = ax.scatter(glam_data['r'], glam_data['s'], c=glam_data[name], cmap=cmap_type, s=size_scatter)
cbar = fig.colorbar(sc, ax=ax)
cbar.set_label(label_cmap, size=size_label, color=color_label)
cbar.ax.tick_params(labelsize=size_axis)

### Save. Do you need save? Use the cell bellow:
fig.savefig(f'z_glam_from_real_data_{name}_en.png', dpi=dpi, bbox_inches='tight')
plt.show()

# %% [markdown]
# #### $\lambda _4$

# %%
### Figure name and DPI
dpi = 600                                                   # Change as you wish
name = 'lambda 4'           # Change as you wish

### Chart dimensions (in centimeters)
b_cm = 12                                                   # Change as you wish
h_cm = 8                                                    # Change as you wish
inches_to_cm = 1 / 2.54
b_input = b_cm * inches_to_cm
h_input = h_cm * inches_to_cm

### Axis and labels (For LateX font format use the dollar sign $)
label_x = 'Resistance ($R$)'                             # Change as you wish
label_y = 'Load ($S$)'                                 # Change as you wish
label_cmap = '$\lambda _4$'                             # Change as you wish
size_label = 13                                             # Change as you wish
color_label = 'black'                                        # or hexadecimal. Change as you wish
size_axis = 13                                              # Change as you wish
color_axis = 'black'                                          # or hexadecimal. Change as you wish

### Scatter
cmap_type = 'seismic'                                          # Change as you wish. Check matplotlib colormaps documentation: https://matplotlib.org/stable/users/explain/colors/colormaps.html
size_scatter = 25                                           # Change as you wish

### Grid
on_or_off = True
line_width_grid = 0.5                                       # Change as you wish
alpha_grid = 0.3                                            # Change as you wish
style_grid = '-'                                            # Change as you wish
color_grid = 'gray'                                         # or hexadecimal. Change as you wish

### Figure
fig, ax = plt.subplots(figsize=(b_input, h_input))
ax.tick_params(axis='both', which='major', labelsize=size_axis, colors=color_axis)
ax.set_xlabel(label_x, fontsize=size_label, color=color_label)
ax.set_ylabel(label_y, fontsize=size_label, color=color_label)

### Title. Do you need a title? Use the cell bellow:
# ax.set_title('Sine Wave Plot', fontsize=16)

### Config grid
plt.grid(on_or_off, which='both', linestyle=style_grid, linewidth=line_width_grid, color=color_grid, alpha=alpha_grid)

### Plot data
sc = ax.scatter(glam_data['r'], glam_data['s'], c=glam_data[name], cmap=cmap_type, s=size_scatter)
cbar = fig.colorbar(sc, ax=ax)
cbar.set_label(label_cmap, size=size_label, color=color_label)
cbar.ax.tick_params(labelsize=size_axis)

### Save. Do you need save? Use the cell bellow:
fig.savefig(f'z_glam_from_real_data_{name}_en.png', dpi=dpi, bbox_inches='tight')
plt.show()

# %% [markdown]
# ### Portuguese version

# %% [markdown]
# #### $\lambda _1$

# %%
### ome e DPI
dpi = 600                                                   # Change as you wish
name = 'lambda 1'           # Change as you wish

### Chart dimensions (in centimeters)
b_cm = 12                                                   # Change as you wish
h_cm = 8                                                    # Change as you wish
inches_to_cm = 1 / 2.54
b_input = b_cm * inches_to_cm
h_input = h_cm * inches_to_cm

### Axis and labels (For LateX font format use the dollar sign $)
label_x = 'Resistência ($R$)'                             # Change as you wish
label_y = 'Solicitação ($S$)'                                 # Change as you wish
label_cmap = '$\lambda _1$'                             # Change as you wish
size_label = 13                                             # Change as you wish
color_label = 'black'                                        # or hexadecimal. Change as you wish
size_axis = 13                                              # Change as you wish
color_axis = 'black'                                          # or hexadecimal. Change as you wish

### Scatter
cmap_type = 'seismic'                                          # Change as you wish. Check matplotlib colormaps documentation: https://matplotlib.org/stable/users/explain/colors/colormaps.html
size_scatter = 25                                           # Change as you wish

### Grid
on_or_off = True
line_width_grid = 0.5                                       # Change as you wish
alpha_grid = 0.3                                            # Change as you wish
style_grid = '-'                                            # Change as you wish
color_grid = 'gray'                                         # or hexadecimal. Change as you wish

### Figure
fig, ax = plt.subplots(figsize=(b_input, h_input))
ax.tick_params(axis='both', which='major', labelsize=size_axis, colors=color_axis)
ax.set_xlabel(label_x, fontsize=size_label, color=color_label)
ax.set_ylabel(label_y, fontsize=size_label, color=color_label)

### Title. Do you need a title? Use the cell bellow:
# ax.set_title('Sine Wave Plot', fontsize=16)

### Config grid
plt.grid(on_or_off, which='both', linestyle=style_grid, linewidth=line_width_grid, color=color_grid, alpha=alpha_grid)

### Plot data
sc = ax.scatter(glam_data['r'], glam_data['s'], c=glam_data[name], cmap=cmap_type, s=size_scatter)
cbar = fig.colorbar(sc, ax=ax)
cbar.set_label(label_cmap, size=size_label, color=color_label)
cbar.ax.tick_params(labelsize=size_axis)

### Save. Do you need save? Use the cell bellow:
fig.savefig(f'z_glam_from_real_data_{name}_pt.png', dpi=dpi, bbox_inches='tight')
plt.show()

# %% [markdown]
# #### $\lambda _2$

# %%
### ome e DPI
dpi = 600                                                   # Change as you wish
name = 'lambda 2'           # Change as you wish

### Chart dimensions (in centimeters)
b_cm = 12                                                   # Change as you wish
h_cm = 8                                                    # Change as you wish
inches_to_cm = 1 / 2.54
b_input = b_cm * inches_to_cm
h_input = h_cm * inches_to_cm

### Axis and labels (For LateX font format use the dollar sign $)
label_x = 'Resistência ($R$)'                             # Change as you wish
label_y = 'Solicitação ($S$)'                                 # Change as you wish
label_cmap = '$\lambda _2$'                             # Change as you wish
size_label = 13                                             # Change as you wish
color_label = 'black'                                        # or hexadecimal. Change as you wish
size_axis = 13                                              # Change as you wish
color_axis = 'black'                                          # or hexadecimal. Change as you wish

### Scatter
cmap_type = 'seismic'                                          # Change as you wish. Check matplotlib colormaps documentation: https://matplotlib.org/stable/users/explain/colors/colormaps.html
size_scatter = 25                                           # Change as you wish

### Grid
on_or_off = True
line_width_grid = 0.5                                       # Change as you wish
alpha_grid = 0.3                                            # Change as you wish
style_grid = '-'                                            # Change as you wish
color_grid = 'gray'                                         # or hexadecimal. Change as you wish

### Figure
fig, ax = plt.subplots(figsize=(b_input, h_input))
ax.tick_params(axis='both', which='major', labelsize=size_axis, colors=color_axis)
ax.set_xlabel(label_x, fontsize=size_label, color=color_label)
ax.set_ylabel(label_y, fontsize=size_label, color=color_label)

### Title. Do you need a title? Use the cell bellow:
# ax.set_title('Sine Wave Plot', fontsize=16)

### Config grid
plt.grid(on_or_off, which='both', linestyle=style_grid, linewidth=line_width_grid, color=color_grid, alpha=alpha_grid)

### Plot data
sc = ax.scatter(glam_data['r'], glam_data['s'], c=glam_data[name], cmap=cmap_type, s=size_scatter)
cbar = fig.colorbar(sc, ax=ax)
cbar.set_label(label_cmap, size=size_label, color=color_label)
cbar.ax.tick_params(labelsize=size_axis)

### Save. Do you need save? Use the cell bellow:
fig.savefig(f'z_glam_from_real_data_{name}_pt.png', dpi=dpi, bbox_inches='tight')
plt.show()

# %% [markdown]
# #### $\lambda _3$

# %%
### ome e DPI
dpi = 600                                                   # Change as you wish
name = 'lambda 3'           # Change as you wish

### Chart dimensions (in centimeters)
b_cm = 12                                                   # Change as you wish
h_cm = 8                                                    # Change as you wish
inches_to_cm = 1 / 2.54
b_input = b_cm * inches_to_cm
h_input = h_cm * inches_to_cm

### Axis and labels (For LateX font format use the dollar sign $)
label_x = 'Resistência ($R$)'                             # Change as you wish
label_y = 'Solicitação ($S$)'                                 # Change as you wish
label_cmap = '$\lambda _3$'                             # Change as you wish
size_label = 13                                             # Change as you wish
color_label = 'black'                                        # or hexadecimal. Change as you wish
size_axis = 13                                              # Change as you wish
color_axis = 'black'                                          # or hexadecimal. Change as you wish

### Scatter
cmap_type = 'seismic'                                          # Change as you wish. Check matplotlib colormaps documentation: https://matplotlib.org/stable/users/explain/colors/colormaps.html
size_scatter = 25                                           # Change as you wish

### Grid
on_or_off = True
line_width_grid = 0.5                                       # Change as you wish
alpha_grid = 0.3                                            # Change as you wish
style_grid = '-'                                            # Change as you wish
color_grid = 'gray'                                         # or hexadecimal. Change as you wish

### Figure
fig, ax = plt.subplots(figsize=(b_input, h_input))
ax.tick_params(axis='both', which='major', labelsize=size_axis, colors=color_axis)
ax.set_xlabel(label_x, fontsize=size_label, color=color_label)
ax.set_ylabel(label_y, fontsize=size_label, color=color_label)

### Title. Do you need a title? Use the cell bellow:
# ax.set_title('Sine Wave Plot', fontsize=16)

### Config grid
plt.grid(on_or_off, which='both', linestyle=style_grid, linewidth=line_width_grid, color=color_grid, alpha=alpha_grid)

### Plot data
sc = ax.scatter(glam_data['r'], glam_data['s'], c=glam_data[name], cmap=cmap_type, s=size_scatter)
cbar = fig.colorbar(sc, ax=ax)
cbar.set_label(label_cmap, size=size_label, color=color_label)
cbar.ax.tick_params(labelsize=size_axis)

### Save. Do you need save? Use the cell bellow:
fig.savefig(f'z_glam_from_real_data_{name}_pt.png', dpi=dpi, bbox_inches='tight')
plt.show()

# %% [markdown]
# #### $\lambda _4$

# %%
### ome e DPI
dpi = 600                                                   # Change as you wish
name = 'lambda 4'           # Change as you wish

### Chart dimensions (in centimeters)
b_cm = 12                                                   # Change as you wish
h_cm = 8                                                    # Change as you wish
inches_to_cm = 1 / 2.54
b_input = b_cm * inches_to_cm
h_input = h_cm * inches_to_cm

### Axis and labels (For LateX font format use the dollar sign $)
label_x = 'Resistência ($R$)'                             # Change as you wish
label_y = 'Solicitação ($S$)'                                 # Change as you wish
label_cmap = '$\lambda _4$'                             # Change as you wish
size_label = 13                                             # Change as you wish
color_label = 'black'                                        # or hexadecimal. Change as you wish
size_axis = 13                                              # Change as you wish
color_axis = 'black'                                          # or hexadecimal. Change as you wish

### Scatter
cmap_type = 'seismic'                                          # Change as you wish. Check matplotlib colormaps documentation: https://matplotlib.org/stable/users/explain/colors/colormaps.html
size_scatter = 25                                           # Change as you wish

### Grid
on_or_off = True
line_width_grid = 0.5                                       # Change as you wish
alpha_grid = 0.3                                            # Change as you wish
style_grid = '-'                                            # Change as you wish
color_grid = 'gray'                                         # or hexadecimal. Change as you wish

### Figure
fig, ax = plt.subplots(figsize=(b_input, h_input))
ax.tick_params(axis='both', which='major', labelsize=size_axis, colors=color_axis)
ax.set_xlabel(label_x, fontsize=size_label, color=color_label)
ax.set_ylabel(label_y, fontsize=size_label, color=color_label)

### Title. Do you need a title? Use the cell bellow:
# ax.set_title('Sine Wave Plot', fontsize=16)

### Config grid
plt.grid(on_or_off, which='both', linestyle=style_grid, linewidth=line_width_grid, color=color_grid, alpha=alpha_grid)

### Plot data
sc = ax.scatter(glam_data['r'], glam_data['s'], c=glam_data[name], cmap=cmap_type, s=size_scatter)
cbar = fig.colorbar(sc, ax=ax)
cbar.set_label(label_cmap, size=size_label, color=color_label)
cbar.ax.tick_params(labelsize=size_axis)

### Save. Do you need save? Use the cell bellow:
fig.savefig(f'z_glam_from_real_data_{name}_pt.png', dpi=dpi, bbox_inches='tight')
plt.show()
