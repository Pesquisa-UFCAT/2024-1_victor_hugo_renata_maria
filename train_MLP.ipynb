# %% [markdown]
# # Libraries

# %%
import os
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
from sklearn.linear_model import LinearRegression, Ridge, Lasso
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor, HistGradientBoostingRegressor
import joblib
import matplotlib.pyplot as plt
import matplotlib as mpl
mpl.rcParams.update({
                        'font.family': 'serif',
                        'mathtext.fontset': 'cm',
                        'axes.unicode_minus': False
                    })
from sklearn.neural_network import MLPRegressor
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import make_pipeline

# %% [markdown]
# # Data upload

# %%
df = pd.read_excel('rccarbonation.xlsx')
df = df.rename(columns={'Possan': 'carb. depth (mm)'})
df = df.rename(columns={'CCO₂ (%)': 'CO2 (%)'})
df.head()
# Out:
#    CO2 (%)  fc (MPa)  RH (%) Type of cement Exposure conditions  t (years)  \
# 0     0.08      25.9    35.4         CPII Z                PIA           9
# 1     0.07      21.7    43.8      CPV - ARI                UEA          92
# 2     0.08      30.3    83.7           CPIV                UEA          58
# 3     0.15      22.8    37.6           CPIV                PIA          42
# 4     0.03      26.4    65.2         CPII F                UEA          96
#
#    carb. depth (mm)
# 0           10.1384
# 1           23.2231
# 2           13.2715
# 3           45.1498
# 4           22.6178

# %% [markdown]
# ### Convert categorical text data to numeric codes

# %%
mapping_dict = {
                    r'\bPIA\b': '0', r'\bUEA\b': '1', r'\bPEA\b': '2',
                    r'\bCPII Z\b': '0', r'\bCPV - ARI\b': '1', r'\bCPIV\b': '2',
                    r'\bCPII F\b': '3', r'\bCPIII\b': '4', r'\bCPII E\b': '5',
               }
df.replace(mapping_dict, regex=True, inplace=True)    
for col in ['Exposure conditions', 'Type of cement']:
    df[col] = pd.to_numeric(df[col])
df.head()
# Out:
#    CO2 (%)  fc (MPa)  RH (%)  Type of cement  Exposure conditions  t (years)  \
# 0     0.08      25.9    35.4               0                    0          9
# 1     0.07      21.7    43.8               1                    1         92
# 2     0.08      30.3    83.7               2                    1         58
# 3     0.15      22.8    37.6               2                    0         42
# 4     0.03      26.4    65.2               3                    1         96
#
#    carb. depth (mm)
# 0           10.1384
# 1           23.2231
# 2           13.2715
# 3           45.1498
# 4           22.6178

# %% [markdown]
# # Train mutiple models with different random states to choose the best one
#
# $n_{folds}$ = 10

# %%
random_states = [42, 7, 21, 35, 14, 28, 56, 63, 84, 91]   # Change as you wish

# %% [markdown]
# ### Models

# %%
mlp_pipeline = make_pipeline(StandardScaler(), 
                             MLPRegressor(hidden_layer_sizes=(100, 50), 
                                          activation='relu', 
                                          solver='adam', 
                                          max_iter=2000, 
                                          random_state=42))

ia_models = {
    "LinearRegression": LinearRegression(),
    "Ridge": Ridge(),
    "Lasso": Lasso(),
    "DecisionTree": DecisionTreeRegressor(random_state=42),
    "RandomForest": RandomForestRegressor(random_state=42),
    "GradientBoosting": GradientBoostingRegressor(random_state=42),
    "HistGradientBoosting": HistGradientBoostingRegressor(random_state=42),
    "NeuralNetwork_MLP": mlp_pipeline  # <--- NOVA LINHA ADICIONADA
}

# %% [markdown]
# ### Folder for saving models and split data

# %%
os.makedirs('models', exist_ok=True)

# %% [markdown]
# ### Train

# %%
dict = {"LinearRegression train": [], "LinearRegression test": [], "Ridge train": [], "Ridge test": [], "Lasso train": [], "Lasso test": [], "DecisionTree train": [], "DecisionTree test": [], "RandomForest train": [], "RandomForest test": [], "GradientBoosting train": [], "GradientBoosting test": [], "HistGradientBoosting train": [], "HistGradientBoosting test": [], "NeuralNetwork_MLP train": [], "NeuralNetwork_MLP test": []}
for model_name, model in ia_models.items():
    print(f"Treinando {model_name}...")
    x = df.drop(columns=['carb. depth (mm)'])
    y = df['carb. depth (mm)']
    for i, state in enumerate(random_states):
        # Split the data
        x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=state)
        
        # Train the model
        model.fit(x_train, y_train)

        # Evaluate the model
        r2_train = r2_score(y_train, model.predict(x_train))
        r2_test = r2_score(y_test, model.predict(x_test))
        
        # Save results and model
        print(f'Fold {i+1}/{len(random_states)} - R² score in training: {r2_train:.3f} - R² score in testing: {r2_test:.3f}')
        dict[f"{model_name} train"].append(r2_train)
        dict[f"{model_name} test"].append(r2_test)
        model_filename = f'models/model_{model_name}_fold_{i+1}.pkl'
        joblib.dump(model, model_filename)
        
        # Save the data splits
        fold_data = {'metadata': f"This pkl contains the data splits",
            'x_train': x_train,
            'x_test': x_test,
            'y_train': y_train,
            'y_test': y_test
        }
        data_filename = f'models/fold_data_{model_name}_fold_{i+1}.pkl'
        joblib.dump(fold_data, data_filename)
# Out:
# Treinando LinearRegression...
# Fold 1/10 - R² score in training: 0.543 - R² score in testing: 0.550
# Fold 2/10 - R² score in training: 0.546 - R² score in testing: 0.539
# Fold 3/10 - R² score in training: 0.545 - R² score in testing: 0.540
# Fold 4/10 - R² score in training: 0.546 - R² score in testing: 0.538
# Fold 5/10 - R² score in training: 0.547 - R² score in testing: 0.535
# Fold 6/10 - R² score in training: 0.546 - R² score in testing: 0.535
# Fold 7/10 - R² score in training: 0.543 - R² score in testing: 0.549
# Fold 8/10 - R² score in training: 0.546 - R² score in testing: 0.538
# Fold 9/10 - R² score in training: 0.542 - R² score in testing: 0.555
# Fold 10/10 - R² score in training: 0.546 - R² score in testing: 0.537
# Treinando Ridge...
# Fold 1/10 - R² score in training: 0.543 - R² score in testing: 0.550
# Fold 2/10 - R² score in training: 0.546 - R² score in testing: 0.539
# Fold 3/10 - R² score in training: 0.545 - R² score in testing: 0.540
# Fold 4/10 - R² score in training: 0.546 - R² score in testing: 0.538
# Fold 5/10 - R² score in training: 0.547 - R² score in testing: 0.535
# Fold 6/10 - R² score in training: 0.546 - R² score in testing: 0.535
# Fold 7/10 - R² score in training: 0.543 - R² score in testing: 0.549
# Fold 8/10 - R² score in training: 0.546 - R² score in testing: 0.538
# Fold 9/10 - R² score in training: 0.542 - R² score in testing: 0.555
# Fold 10/10 - R² score in training: 0.546 - R² score in testing: 0.537
# Treinando Lasso...
# Fold 1/10 - R² score in training: 0.531 - R² score in testing: 0.536
# Fold 2/10 - R² score in training: 0.534 - R² score in testing: 0.532
# Fold 3/10 - R² score in training: 0.534 - R² score in testing: 0.532
# Fold 4/10 - R² score in training: 0.534 - R² score in testing: 0.525
# Fold 5/10 - R² score in training: 0.535 - R² score in testing: 0.527
# Fold 6/10 - R² score in training: 0.535 - R² score in testing: 0.522
# Fold 7/10 - R² score in training: 0.532 - R² score in testing: 0.541
# Fold 8/10 - R² score in training: 0.534 - R² score in testing: 0.525
# Fold 9/10 - R² score in training: 0.531 - R² score in testing: 0.544
# Fold 10/10 - R² score in training: 0.535 - R² score in testing: 0.527
# Treinando DecisionTree...
# Fold 1/10 - R² score in training: 1.000 - R² score in testing: 0.914
# Fold 2/10 - R² score in training: 1.000 - R² score in testing: 0.921
# Fold 3/10 - R² score in training: 1.000 - R² score in testing: 0.923
# Fold 4/10 - R² score in training: 1.000 - R² score in testing: 0.918
# Fold 5/10 - R² score in training: 1.000 - R² score in testing: 0.916
# Fold 6/10 - R² score in training: 1.000 - R² score in testing: 0.921
# Fold 7/10 - R² score in training: 1.000 - R² score in testing: 0.920
# Fold 8/10 - R² score in training: 1.000 - R² score in testing: 0.913
# Fold 9/10 - R² score in training: 1.000 - R² score in testing: 0.907
# Fold 10/10 - R² score in training: 1.000 - R² score in testing: 0.918
# Treinando RandomForest...
# Fold 1/10 - R² score in training: 0.995 - R² score in testing: 0.958
# Fold 2/10 - R² score in training: 0.995 - R² score in testing: 0.963
# Fold 3/10 - R² score in training: 0.995 - R² score in testing: 0.962
# Fold 4/10 - R² score in training: 0.995 - R² score in testing: 0.965
# Fold 5/10 - R² score in training: 0.995 - R² score in testing: 0.964
# Fold 6/10 - R² score in training: 0.995 - R² score in testing: 0.964
# Fold 7/10 - R² score in training: 0.995 - R² score in testing: 0.961
# Fold 8/10 - R² score in training: 0.994 - R² score in testing: 0.960
# Fold 9/10 - R² score in training: 0.995 - R² score in testing: 0.958
# Fold 10/10 - R² score in training: 0.995 - R² score in testing: 0.966
# Treinando GradientBoosting...
# Fold 1/10 - R² score in training: 0.951 - R² score in testing: 0.947
# Fold 2/10 - R² score in training: 0.951 - R² score in testing: 0.940
# Fold 3/10 - R² score in training: 0.949 - R² score in testing: 0.939
# Fold 4/10 - R² score in training: 0.951 - R² score in testing: 0.944
# Fold 5/10 - R² score in training: 0.952 - R² score in testing: 0.941
# Fold 6/10 - R² score in training: 0.951 - R² score in testing: 0.944
# Fold 7/10 - R² score in training: 0.951 - R² score in testing: 0.946
# Fold 8/10 - R² score in training: 0.951 - R² score in testing: 0.940
# Fold 9/10 - R² score in training: 0.951 - R² score in testing: 0.953
# Fold 10/10 - R² score in training: 0.952 - R² score in testing: 0.945
# Treinando HistGradientBoosting...
# Fold 1/10 - R² score in training: 0.995 - R² score in testing: 0.992
# Fold 2/10 - R² score in training: 0.996 - R² score in testing: 0.993
# Fold 3/10 - R² score in training: 0.996 - R² score in testing: 0.993
# Fold 4/10 - R² score in training: 0.996 - R² score in testing: 0.993
# Fold 5/10 - R² score in training: 0.996 - R² score in testing: 0.993
# Fold 6/10 - R² score in training: 0.996 - R² score in testing: 0.992
# Fold 7/10 - R² score in training: 0.995 - R² score in testing: 0.993
# Fold 8/10 - R² score in training: 0.996 - R² score in testing: 0.993
# Fold 9/10 - R² score in training: 0.996 - R² score in testing: 0.992
# Fold 10/10 - R² score in training: 0.996 - R² score in testing: 0.993
# Treinando NeuralNetwork_MLP...
# Fold 1/10 - R² score in training: 0.999 - R² score in testing: 0.999
# Fold 2/10 - R² score in training: 0.999 - R² score in testing: 0.999
# Fold 3/10 - R² score in training: 0.999 - R² score in testing: 0.999
# Fold 4/10 - R² score in training: 0.999 - R² score in testing: 0.999
# Fold 5/10 - R² score in training: 0.999 - R² score in testing: 0.999
# Fold 6/10 - R² score in training: 0.999 - R² score in testing: 0.999
# Fold 7/10 - R² score in training: 0.999 - R² score in testing: 0.999
# Fold 8/10 - R² score in training: 0.999 - R² score in testing: 0.999
# Fold 9/10 - R² score in training: 0.999 - R² score in testing: 0.998
# Fold 10/10 - R² score in training: 0.999 - R² score in testing: 0.999

# %% [markdown]
# #### Final statistics

# %%
dict_df = pd.DataFrame(dict)
dict_df
# Out:
#    LinearRegression train  LinearRegression test  Ridge train  Ridge test  \
# 0                0.542581               0.550491     0.542581    0.550482
# 1                0.545693               0.538720     0.545693    0.538719
# 2                0.545371               0.539654     0.545371    0.539661
# 3                0.545683               0.537903     0.545683    0.537915
# 4                0.546533               0.534568     0.546533    0.534558
# 5                0.546470               0.535380     0.546470    0.535375
# 6                0.543030               0.549297     0.543030    0.549298
# 7                0.545887               0.537913     0.545887    0.537914
# 8                0.541856               0.554569     0.541856    0.554569
# 9                0.546001               0.536965     0.546001    0.536972
#
#    Lasso train  Lasso test  DecisionTree train  DecisionTree test  \
# 0     0.531256    0.536338                 1.0           0.914298
# 1     0.533946    0.531589                 1.0           0.921223
# 2     0.533886    0.532446                 1.0           0.922733
# 3     0.534395    0.525137                 1.0           0.918211
# 4     0.535446    0.526885                 1.0           0.916498
# 5     0.534966    0.521657                 1.0           0.920548
# 6     0.531772    0.540930                 1.0           0.920483
# 7     0.534450    0.524690                 1.0           0.913299
# 8     0.530845    0.544314                 1.0           0.906986
# 9     0.534716    0.527156                 1.0           0.918016
#
#    RandomForest train  RandomForest test  GradientBoosting train  \
# 0            0.994500           0.958347                0.950759
# 1            0.994674           0.963482                0.951087
# 2            0.994605           0.962320                0.948651
# 3            0.994598           0.965022                0.950827
# 4            0.994688           0.963717                0.951682
# 5            0.994716           0.964066                0.950755
# 6            0.994627           0.961377                0.951398
# 7            0.994435           0.959820                0.951176
# 8            0.994655           0.958334                0.951069
# 9            0.994708           0.966047                0.951769
#
#    GradientBoosting test  HistGradientBoosting train  \
# 0               0.946825                    0.995476
# 1               0.940308                    0.995595
# 2               0.938852                    0.995773
# 3               0.944351                    0.995765
# 4               0.940681                    0.995613
# 5               0.944428                    0.995515
# 6               0.946450                    0.995353
# 7               0.940071                    0.995735
# 8               0.952604                    0.995565
# 9               0.944699                    0.995916
#
#    HistGradientBoosting test  NeuralNetwork_MLP train  NeuralNetwork_MLP test
# 0                   0.992224                 0.999254                0.998786
# 1                   0.992938                 0.999124                0.998937
# 2                   0.992730                 0.999111                0.998690
# 3                   0.993458                 0.999396                0.998977
# 4                   0.992531                 0.999296                0.998968
# 5                   0.992390                 0.999056                0.998702
# 6                   0.992546                 0.999262                0.998933
# 7                   0.992626                 0.999019                0.998674
# 8                   0.991777                 0.998770                0.998432
# 9                   0.993446                 0.999098                0.998777

# %% [markdown]
# #### Best fold best model

# %%
test_column = [col for col in dict_df.columns if 'test' in col]

mean = dict_df[test_column].mean()
best_model_column = mean.idxmax() # Ex: 'NeuralNetwork_MLP test'
best_model_name = best_model_column.replace(' test', '') # Tira o ' test' do nome
best_fold = dict_df[best_model_column].idxmax()
best_score = dict_df[best_model_column][best_fold]
print(f"   Best Fold: {best_fold + 1}")
print(f"   R² Score: {best_score:.5f}")
name_best_model = f'models/model_{best_model_name}_fold_{best_fold + 1}.pkl'
name_best_fold_data = f'models/fold_data_{best_model_name}_fold_{best_fold + 1}.pkl'

print(f"\n'{name_best_model}'")
# Out:
#    Best Fold: 4
#    R² Score: 0.99898
#
# 'models/model_NeuralNetwork_MLP_fold_4.pkl'

# %% [markdown]
# #### Plot in LateX

# %%
stats = dict_df.describe().T
stats = stats[['mean', 'std']]
stats
# Out:
#                                 mean       std
# LinearRegression train      0.544911  0.001729
# LinearRegression test       0.541546  0.007114
# Ridge train                 0.544911  0.001729
# Ridge test                  0.541546  0.007113
# Lasso train                 0.533568  0.001650
# Lasso test                  0.531114  0.007452
# DecisionTree train          1.000000  0.000000
# DecisionTree test           0.917230  0.004701
# RandomForest train          0.994621  0.000091
# RandomForest test           0.962253  0.002714
# GradientBoosting train      0.950917  0.000873
# GradientBoosting test       0.943927  0.004154
# HistGradientBoosting train  0.995631  0.000167
# HistGradientBoosting test   0.992667  0.000517
# NeuralNetwork_MLP train     0.999139  0.000176
# NeuralNetwork_MLP test      0.998787  0.000173

# %%
stt = stats.to_latex(float_format="%.2f")
print(stt)
# Out:
# \begin{tabular}{lrr}
# \toprule
#  & mean & std \\
# \midrule
# LinearRegression train & 0.54 & 0.00 \\
# LinearRegression test & 0.54 & 0.01 \\
# Ridge train & 0.54 & 0.00 \\
# Ridge test & 0.54 & 0.01 \\
# Lasso train & 0.53 & 0.00 \\
# Lasso test & 0.53 & 0.01 \\
# DecisionTree train & 1.00 & 0.00 \\
# DecisionTree test & 0.92 & 0.00 \\
# RandomForest train & 0.99 & 0.00 \\
# RandomForest test & 0.96 & 0.00 \\
# GradientBoosting train & 0.95 & 0.00 \\
# GradientBoosting test & 0.94 & 0.00 \\
# HistGradientBoosting train & 1.00 & 0.00 \\
# HistGradientBoosting test & 0.99 & 0.00 \\
# NeuralNetwork_MLP train & 1.00 & 0.00 \\
# NeuralNetwork_MLP test & 1.00 & 0.00 \\
# \bottomrule
# \end{tabular}

# %% [markdown]
# # Predicted versus Observed plot for the best model and Worst model

# %% [markdown]
# ### Load best model and predict

# %%
model = joblib.load(name_best_model)
x_test = joblib.load(name_best_fold_data)['x_test']
y_obs = joblib.load(name_best_fold_data)['y_test']
y_pred = model.predict(x_test)
data = pd.DataFrame({
                        "Observed": y_obs,
                        "Predicted": y_pred
                    })

# %% [markdown]
# ### Plot best model

# %%
import joblib
import pandas as pd
import matplotlib.pyplot as plt

try:
    #1. Processing data for test {name_best_fold_data}
    fold_data = joblib.load(name_best_fold_data)
    X_test = fold_data['x_test']  # Recupering the test features
    y_test = fold_data['y_test']  # Recupering the true labels

    #2. Processing model: {name_best_model}
    model = joblib.load(name_best_model) # Process the best model file 

    #3. Predicting (y_pred)
    y_pred = model.predict(X_test) 

    # 4. Preparing data for plotting
    data = pd.DataFrame({
        "Observed": y_test, 
        "Predicted": y_pred
    })

except Exception as e:
    print(f"Error {e}")
    data = pd.DataFrame({"Observed": [0], "Predicted": [0]})

### Figure name and DPI
dpi = 600
# Limpa o nome para o arquivo
clean_name = best_model_name.replace("NeuralNetwork_", "NN_").replace("GradientBoosting", "GB")
name = f'z_scatter_{clean_name}' 

### Chart dimensions
b_cm = 10
h_cm = 10
inches_to_cm = 1 / 2.54
b_input = b_cm * inches_to_cm
h_input = h_cm * inches_to_cm

### Axis and labels
label_x = 'Observed'
label_y = 'Predicted'
size_label = 14
color_label = 'black'
size_axis = 14
color_axis = 'black'

### Line
size_line = 2
style_line = '-'
color_line = 'red'

### Scatter
alpha_scatter = 0.3
color_scatter = 'blue'
size_scatter = 25

### Legend
# Global variables 'best_model_name' e 'best_score'
labels_legend = f'{clean_name.replace("_", " ")} $R^2$ = {best_score:.4f}'
size_legend = 10
location_legend = 'upper left'

### Grid
on_or_off = True
line_width_grid = 0.5
alpha_grid = 0.3
style_grid = '--'
color_grid = 'gray'

# Max and min axis limits
if len(data) > 1:
    lims = [min(data.min()), max(data.max())]
else:
    lims = [0, 1] 

### Figure
fig, ax = plt.subplots(figsize=(b_input, h_input))
ax.tick_params(axis='both', which='major', labelsize=size_axis, colors=color_axis)
ax.set_xlabel(label_x, fontsize=size_label, color=color_label)
ax.set_ylabel(label_y, fontsize=size_label, color=color_label)

### Config grid
plt.grid(on_or_off, which='both', linestyle=style_grid, linewidth=line_width_grid, color=color_grid, alpha=alpha_grid)

### Plot data and legend
ax.plot(lims, lims, linewidth=size_line, linestyle=style_line, color=color_line)
ax.scatter(data["Observed"], data["Predicted"], alpha=alpha_scatter, color=color_scatter, s=size_scatter, label=labels_legend)

ax.legend(fontsize=size_legend, loc=location_legend)

### Save
filename = f'{name}_en.png'
print(f"Salving graph: {filename}")
fig.savefig(filename, dpi=dpi, bbox_inches='tight')
plt.show()
# Out:
# Salving graph: z_scatter_NN_MLP_en.png

# %% [markdown]
# ### Load worst model and predict

# %%
test_column = [col for col in dict_df.columns if 'test' in col]

# 1. Process to find the worst model
mean = dict_df[test_column].mean()
worst_model_column = mean.idxmin() # Ex: 'LinearRegression test'
worst_model_name = worst_model_column.replace(' test', '')

# 2. Find the worst fold for that model
worst_fold = dict_df[worst_model_column].idxmin()
worst_score = dict_df[worst_model_column][worst_fold]
print(f"\nWorst Model: {worst_model_name}")
print(f"   Worst Fold: {worst_fold + 1}")
print(f"   R² Score: {worst_score:.5f}")

# 3. File names
name_worst_model = f'models/model_{worst_model_name}_fold_{worst_fold + 1}.pkl'
name_worst_fold_data = f'models/fold_data_{worst_model_name}_fold_{worst_fold + 1}.pkl'
# Out:
# Worst Model: Lasso
#    Worst Fold: 6
#    R² Score: 0.52166

# %%
model = joblib.load(name_worst_model)
x_test = joblib.load(name_worst_fold_data)['x_test']
y_obs = joblib.load(name_worst_fold_data)['y_test']
y_pred = model.predict(x_test)
data = pd.DataFrame({
                        "Observed": y_obs,
                        "Predicted": y_pred
                    })

# %% [markdown]
# ### Plot worst model

# %%
import joblib
import pandas as pd
import matplotlib.pyplot as plt

try:
    # 1. Processing data for test 
    fold_data = joblib.load(name_worst_fold_data)
    X_test_worst = fold_data['x_test']
    y_test_worst = fold_data['y_test']

    # 2. Processing model
    model_worst = joblib.load(name_worst_model)

    # 3. Predicting
    y_pred_worst = model_worst.predict(X_test_worst)

    # 4. Preparing data for plotting
    data = pd.DataFrame({
        "Observed": y_test_worst, 
        "Predicted": y_pred_worst
    })

except Exception as e:
    print(f"Error: {e}")
    data = pd.DataFrame({"Observed": [0], "Predicted": [0]})

### Figure name and DPI
dpi = 600                                                   # Change as you wish
name = f'scatter_worst_{worst_model_name}'                  # Change as you wish

### Chart dimensions (in centimeters)
b_cm = 10                                                    # Change as you wish
h_cm = 10                                                    # Change as you wish
inches_to_cm = 1 / 2.54
b_input = b_cm * inches_to_cm
h_input = h_cm * inches_to_cm

### Axis and labels (For LateX font format use the dollar sign $)
label_x = 'Observed'                                         # Change as you wish
label_y = 'Predicted'                                        # Change as you wish
size_label = 14                                              # Change as you wish
color_label = 'black'                                        # or hexadecimal. Change as you wish
size_axis = 14                                               # Change as you wish
color_axis = 'black'                                         # or hexadecimal. Change as you wish

### Line
size_line = 2                                                # Change as you wish
style_line = '--'                                            # Change as you wish
color_line = 'red'                                           # or hexadecimal. Change as you wish

### Scatter
alpha_scatter = 0.4                                          # Change as you wish
color_scatter = 'blue'                                       # Change as you wish
size_scatter = 25                                            # Change as you wish

### Legend
labels_legend = f'{worst_model_name} $R^2$ = {worst_score:.2f}'  # Change as you wish
size_legend = 10                                             # Change as you wish
location_legend = 'upper left'                               # Change as you wish - 'best' look up by the best fit

### Grid
on_or_off = True
line_width_grid = 0.5                                        # Change as you wish
alpha_grid = 0.3                                             # Change as you wish
style_grid = '-'                                             # Change as you wish
color_grid = 'gray'                                          # or hexadecimal. Change as you wish

# Max and min axis limits
if len(data) > 1:
    lims = [
                min(data.min()),
                max(data.max())
            ]   
else:
    lims = [0, 1]

### Figure
fig, ax = plt.subplots(figsize=(b_input, h_input))
ax.tick_params(axis='both', which='major', labelsize=size_axis, colors=color_axis)
ax.set_xlabel(label_x, fontsize=size_label, color=color_label)
ax.set_ylabel(label_y, fontsize=size_label, color=color_label)

### Title
# ax.set_title('Sine Wave Plot', fontsize=16)

### Config grid
plt.grid(on_or_off, which='both', linestyle=style_grid, linewidth=line_width_grid, color=color_grid, alpha=alpha_grid)

### Plot data and legend
# Plota a linha de referência (Ideal)
ax.plot(lims, lims, linewidth=size_line, linestyle=style_line, color=color_line,)
ax.scatter(data["Observed"], data["Predicted"], alpha=alpha_scatter, color=color_scatter, s=size_scatter, label=labels_legend)
ax.legend(fontsize=size_legend, loc=location_legend)

### Save
filename = f'z_{name}_en.png'
print(f"Salving graph {filename}")
fig.savefig(filename, dpi=dpi, bbox_inches='tight')
plt.show()
# Out:
# Salving graph z_scatter_worst_Lasso_en.png
